# %%
from bs4 import BeautifulSoup

# %%
with open('../../data/ref-pipe.html', 'r') as f:
    html_content = f.read()

# %%
soup = BeautifulSoup(html_content)

# %%
soup.find
# Out:
# <bound method Tag.find of <!DOCTYPE html>
#
# <html lang="en" xml:lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta charset="utf-8"/>
# <meta content="pandoc" name="generator"/>
# <meta content="width=device-width, initial-scale=1.0, user-scalable=yes" name="viewport"/>
# <meta content="" name="author"/>
# <title>HTML References Pipeline</title>
# <link href="http://purl.org/dc/terms/" rel="schema.DC"/>
# <meta content="application/pdf" name="DC.Format" scheme="IMT"/>
# <meta content="en" name="DC.Language" scheme="ISO639-1"/>
# <meta content="HTML References Pipeline" name="DC.Title"/>
# <meta content="" name="DC.Creator.PersonalName"/>
# <meta content="10.48106/dial.v74.i1" name="DC.Identifier.DOI"/>
# <meta content="1746-8361" name="DC.Source.ISSN"/>
# <meta content="Text.Serial.Journal" name="DC.Type"/>
# <meta content="Articles" name="DC.Type.articleType"/>
# <meta content="Dialectica" name="DC.Source"/>
# <meta content="https://dialectica.philosophie.ch/" name="DC.Source.URI"/>
# <meta content="Copyright (c) " name="DC.Rights"/>
# <meta content="https://creativecommons.org/licenses/by/4.0" name="DC.Rights"/>
# <link href="https://fonts.googleapis.com" rel="preconnect"/>
# <link crossorigin="" href="https://fonts.gstatic.com" rel="preconnect"/>
# <link href="https://fonts.googleapis.com/css2?family=STIX+Two+Text:ital,wght@0,400;0,700;1,400;1,700&amp;display=swap" rel="stylesheet"/>
# <style>
#     html {
#       color: #1a1a1a;
#       background-color: #fdfdfd;
#     }
#     body {
#       margin: 0 auto;
#       max-width: 36em;
#       padding-left: 50px;
#       padding-right: 50px;
#       padding-top: 50px;
#       padding-bottom: 50px;
#       hyphens: auto;
#       overflow-wrap: break-word;
#       text-rendering: optimizeLegibility;
#       font-kerning: normal;
#     }
#     @media (max-width: 600px) {
#       body {
#         font-size: 0.9em;
#         padding: 12px;
#       }
#       h1 {
#         font-size: 1.8em;
#       }
#     }
#     @media print {
#       html {
#         background-color: white;
#       }
#       body {
#         background-color: transparent;
#         color: black;
#         font-size: 12pt;
#       }
#       p, h2, h3 {
#         orphans: 3;
#         widows: 3;
#       }
#       h2, h3, h4 {
#         page-break-after: avoid;
#       }
#     }
#     p {
#       margin: 1em 0;
#     }
#     a {
#       color: #1a1a1a;
#     }
#     a:visited {
#       color: #1a1a1a;
#     }
#     img {
#       max-width: 100%;
#     }
#     svg {
#       height: auto;
#       max-width: 100%;
#     }
#     h1, h2, h3, h4, h5, h6 {
#       margin-top: 1.4em;
#     }
#     h5, h6 {
#       font-size: 1em;
#       font-style: italic;
#     }
#     h6 {
#       font-weight: normal;
#     }
#     ol, ul {
#       padding-left: 1.7em;
#       margin-top: 1em;
#     }
#     li > ol, li > ul {
#       margin-top: 0;
#     }
#     blockquote {
#       margin: 1em 0 1em 1.7em;
#       padding-left: 1em;
#       border-left: 2px solid #e6e6e6;
#       color: #606060;
#     }
#     code {
#       font-family: Menlo, Monaco, Consolas, 'Lucida Console', monospace;
#       font-size: 85%;
#       margin: 0;
#       hyphens: manual;
#     }
#     pre {
#       margin: 1em 0;
#       overflow: auto;
#     }
#     pre code {
#       padding: 0;
#       overflow: visible;
#       overflow-wrap: normal;
#     }
#     .sourceCode {
#      background-color: transparent;
#      overflow: visible;
#     }
#     hr {
#       background-color: #1a1a1a;
#       border: none;
#       height: 1px;
#       margin: 1em 0;
#     }
#     table {
#       margin: 1em 0;
#       border-collapse: collapse;
#       width: 100%;
#       overflow-x: auto;
#       display: block;
#       font-variant-numeric: lining-nums tabular-nums;
#     }
#     table caption {
#       margin-bottom: 0.75em;
#     }
#     tbody {
#       margin-top: 0.5em;
#       border-top: 1px solid #1a1a1a;
#       border-bottom: 1px solid #1a1a1a;
#     }
#     th {
#       border-top: 1px solid #1a1a1a;
#       padding: 0.25em 0.5em 0.25em 0.5em;
#     }
#     td {
#       padding: 0.125em 0.5em 0.25em 0.5em;
#     }
#     header {
#       margin-bottom: 4em;
#       text-align: center;
#     }
#     #TOC li {
#       list-style: none;
#     }
#     #TOC ul {
#       padding-left: 1.3em;
#     }
#     #TOC > ul {
#       padding-left: 0;
#     }
#     #TOC a:not(:hover) {
#       text-decoration: none;
#     }
#     code{white-space: pre-wrap;}
#     span.smallcaps{font-variant: small-caps;}
#     div.columns{display: flex; gap: min(4vw, 1.5em);}
#     div.column{flex: auto; overflow-x: auto;}
#     div.hanging-indent{margin-left: 1.5em; text-indent: -1.5em;}
#     /* The extra [class] is a hack that increases specificity enough to
#        override a similar rule in reveal.js */
#     ul.task-list[class]{list-style: none;}
#     ul.task-list li input[type="checkbox"] {
#       font-size: inherit;
#       width: 0.8em;
#       margin: 0 0.8em 0.2em -1.6em;
#       vertical-align: middle;
#     }
#     .display.math{display: block; text-align: center; margin: 0.5rem auto;}
#     body{font-family:"STIX Two Text","Times New Roman",Times,serif;font-size:18px;color:#333;background-color:#fff}blockquote,div,li,ol,ul{background-color:inherit}a:any-link{text-decoration-line:none;text-decoration:none}a{color:#084198}a :visited{color:#084198}a :hover{color:#04224f;text-decoration:underline}blockquote{color:#333}header{font-family:"Libertinus Serif Display","Libertinus Serif","STIX Two Text",Times New Roman,Times,serif}header .author{font-size:150%;font-variant-caps:small-caps;letter-spacing:3px;margin-bottom:15px}div.abstract{text-align:justify}.article-body p{text-align:justify}.article-body ol{margin-top:12.5px;margin-bottom:12.5px}.article-body ol ol,.article-body ol ul{margin-bottom:0}.article-body blockquote{padding:12.5px 2em;margin:0 0 25px;font-size:18px;border:none}.article-body span.smallcaps{font-variant:small-caps}.article-body :is(h1,h2,h3){margin:25px 0}.article-body :is(h4,h5,h6){display:inline;padding-right:1em}.article-body :is(h4,h5,h6)+p{display:inline}.article-body :is(h4,h5,h6):before{content:"";display:block;clear:left;margin-top:25px}.article-body :is(h1,h2){font-family:"Libertinus Serif Display","Libertinus Serif","STIX Two Text","Times New Roman",Times,serif;font-size:23px}.article-body :is(h3,h4,h5,h6){font-family:"STIX Two Text","Times New Roman",Times,serif;font-size:18px}.article-body h1{font-weight:700}.article-body h2{font-style:italic}.article-body h4{font-variant:small-caps}.article-body h4 .math.inline{font-variant:normal}.article-body h5{font-style:italic}@media (min-width:768px){.article-body h1 span.header-section-number,.article-body h2 span.header-section-number,.article-body h3 span.header-section-number{display:inline-block;float:left}.article-body :is(h1,h2,h3).unnumbered{margin-left:0;left:0}.article-body h1{margin-left:-1.2em;left:1.2em}.article-body h1 span.header-section-number{width:1.2em}.article-body h2{margin-left:-1.7em;left:1.7em}.article-body h2 span.header-section-number{width:1.7em}.article-body h3{margin-left:-2.5em;left:2.5em}.article-body h3 span.header-section-number{width:2.5em}}@media (min-width:768px){.article-body #footnotes{counter-reset:footnote}.article-body section.footnotes>ol{padding-left:0}.article-body section.footnotes>ol>li{margin-bottom:9px}.article-body section.footnotes>ol>li:before{counter-increment:footnote;content:counter(footnote) ".";position:absolute;left:-1em}}.article-body div.hanging-indent{margin-left:1.5em;text-indent:-1.5em}.article-body div.reviewof{margin-bottom:1em}.article-body div.reviewof p{text-indent:0;margin-bottom:.5em}.article-body p{text-indent:1.5em;margin:0}.article-body header p{text-indent:0;margin:1em 0}.article-body :is(h1,h2,h3,h4,h5,h6)+p{text-indent:0}.article-body li>div p,.article-body li>p{text-indent:0;margin-bottom:1rem}.article-body div.no-first-line-indent-after+p{text-indent:0}.article-body div.first-line-indent-after+p{text-indent:1.5em}.article-body div.labelled-lists-list{margin:1em 0}.article-body div.labelled-lists-list p.labelled-lists-item{text-indent:0;margin-bottom:1rem;padding-left:3em}.article-body div.labelled-lists-list span.labelled-lists-label{display:inline-block;min-width:2.5em;margin-left:-3em;margin-right:.5em}  </style>
# <!--[if lt IE 9]>
#     <script src="//cdnjs.cloudflare.com/ajax/libs/html5shiv/3.7.3/html5shiv-printshiv.min.js"></script>
#   <![endif]-->
# </head>
# <body>
# <header id="title-block-header">
# <h1 class="title">HTML References Pipeline</h1>
# <p class="date">March 2024</p>
# </header>
# <section class="article-body">
# <script src="https://polyfill.io/v3/polyfill.min.js?features=es6"></script>
# <script type="text/x-mathjax-config">
#   MathJax.Hub.Config({
#     "HTML-CSS": {fonts: ['STIX-web']},
#     SVG: {font: 'STIX-Web'},
#     TeX: {Augment: {
#       Definitions: {
#         delimiter: {
#           '\\llbracket': '27E6',
#           '\\rrbracket': '27E7
#         }
#       }
#     }}
#   });
# </script>
# <script src="https://cdn.jsdelivr.net/npm/mathjax@3/es5/tex-chtml-full.js" type="text/javascript"></script>
# <div class="no-first-line-indent-after"></div>
# <p><span class="citation" data-cites="mulligan_k:1980">Mulligan, K. (<a href="#ref-c1-mulligan_k:1980" role="doc-biblioref">1980</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1981">Mulligan, K. (<a href="#ref-c1-mulligan_k:1981" role="doc-biblioref">1981</a>)</span></p>
# <p><span class="citation" data-cites="smith_ba-mulligan:1982">Smith and
# Mulligan (<a href="#ref-c1-smith_ba-mulligan:1982" role="doc-biblioref">1982</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1983">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1983" role="doc-biblioref">1983</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1983">Mulligan, K. (<a href="#ref-c1-mulligan_k:1983" role="doc-biblioref">1983a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1983a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1983a" role="doc-biblioref">1983b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1983b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1983b" role="doc-biblioref">1983c</a>)</span></p>
# <p><span class="citation" data-cites="smith_ba-mulligan:1983">Smith and
# Mulligan (<a href="#ref-c1-smith_ba-mulligan:1983" role="doc-biblioref">1983</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:1984">Mulligan,
# K., Simons and Smith (<a href="#ref-c1-mulligan_k-etal:1984" role="doc-biblioref">1984</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1984">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1984" role="doc-biblioref">1984</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-rug:1985">Mulligan, K.
# and Rug (<a href="#ref-c1-mulligan_k-rug:1985" role="doc-biblioref">1985</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1985">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1985" role="doc-biblioref">1985</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1985">Mulligan, K. (<a href="#ref-c1-mulligan_k:1985" role="doc-biblioref">1985</a>)</span></p>
# <p><span class="citation" data-cites="smith_ba-mulligan:1985">Smith and
# Mulligan (<a href="#ref-c1-smith_ba-mulligan:1985" role="doc-biblioref">1985</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1986">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1986" role="doc-biblioref">1986a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1986a">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1986a" role="doc-biblioref">1986b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-smith:1986b">Mulligan,
# K. and Smith (<a href="#ref-c1-mulligan_k-smith:1986b" role="doc-biblioref">1986c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1986">Mulligan, K. (<a href="#ref-c1-mulligan_k:1986" role="doc-biblioref">1986</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:1987">Mulligan,
# K., Simons and Smith (<a href="#ref-c1-mulligan_k-etal:1987" role="doc-biblioref">1987</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1987">Mulligan, K. (<a href="#ref-c1-mulligan_k:1987" role="doc-biblioref">1987a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1987a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1987a" role="doc-biblioref">1987b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1988">Mulligan, K. (<a href="#ref-c1-mulligan_k:1988" role="doc-biblioref">1988a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1988a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1988a" role="doc-biblioref">1988b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1988b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1988b" role="doc-biblioref">1988c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1988c">Mulligan, K. (<a href="#ref-c1-mulligan_k:1988c" role="doc-biblioref">1988d</a>)</span></p>
# <p><span class="citation" data-cites="smith_ba-mulligan:1988">Smith and
# Mulligan (<a href="#ref-c1-smith_ba-mulligan:1988" role="doc-biblioref">1988</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1989">Mulligan, K. (<a href="#ref-c1-mulligan_k:1989" role="doc-biblioref">1989</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-schuhmann:1990">Mulligan, K. and Schuhmann (<a href="#ref-c1-mulligan_k-schuhmann:1990" role="doc-biblioref">1990</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990" role="doc-biblioref">1990a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990a" role="doc-biblioref">1990b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990b" role="doc-biblioref">1990c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990c">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990c" role="doc-biblioref">1990d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990d">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990d" role="doc-biblioref">1990e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1990e">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990e" role="doc-biblioref">1990f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1991">Mulligan, K. (<a href="#ref-c1-mulligan_k:1991" role="doc-biblioref">1991a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1991a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1991a" role="doc-biblioref">1991b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1991b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1991b" role="doc-biblioref">1991c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1992">Mulligan, K. (<a href="#ref-c1-mulligan_k:1992" role="doc-biblioref">1992</a>)</span></p>
# <p><span class="citation" data-cites="garrett_bj-mulligan:1993">Garrett
# and Mulligan (<a href="#ref-c1-garrett_bj-mulligan:1993" role="doc-biblioref">1993</a>)</span></p>
# <p><span class="citation" data-cites="leyvraz-mulligan:1993">Leyvraz and
# Mulligan (<a href="#ref-c1-leyvraz-mulligan:1993" role="doc-biblioref">1993</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-roth:1993">Mulligan, K.
# and Roth (<a href="#ref-c1-mulligan_k-roth:1993" role="doc-biblioref">1993</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1993">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993" role="doc-biblioref">1993a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1993a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993a" role="doc-biblioref">1993b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1993b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993b" role="doc-biblioref">1993c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1993c">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993c" role="doc-biblioref">1993d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1995">Mulligan, K. (<a href="#ref-c1-mulligan_k:1995" role="doc-biblioref">1995a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1995a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1995a" role="doc-biblioref">1995b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1995b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1995b" role="doc-biblioref">1995c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1996">Mulligan, K. (<a href="#ref-c1-mulligan_k:1996" role="doc-biblioref">1996</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997" role="doc-biblioref">1997a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997a" role="doc-biblioref">1997b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997b" role="doc-biblioref">1997c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997c">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997c" role="doc-biblioref">1997d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997d">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997d" role="doc-biblioref">1997e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1997e">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997e" role="doc-biblioref">1997f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_r-etal:1997">Mulligan,
# R., Mulligan and Juillerat (<a href="#ref-c1-mulligan_r-etal:1997" role="doc-biblioref">1997</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1998">Mulligan, K. (<a href="#ref-c1-mulligan_k:1998" role="doc-biblioref">1998a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1998a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1998a" role="doc-biblioref">1998b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1999">Mulligan, K. (<a href="#ref-c1-mulligan_k:1999" role="doc-biblioref">1999a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1999a">Mulligan, K. (<a href="#ref-c1-mulligan_k:1999a" role="doc-biblioref">1999b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1999b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1999b" role="doc-biblioref">1999c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:1999c">Mulligan, K. (<a href="#ref-c1-mulligan_k:1999c" role="doc-biblioref">1999d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2000">Mulligan, K. (<a href="#ref-c1-mulligan_k:2000" role="doc-biblioref">2000a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2000a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2000a" role="doc-biblioref">2000b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2000b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2000b" role="doc-biblioref">2000c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2000c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2000c" role="doc-biblioref">2000d</a>)</span></p>
# <p><span class="citation" data-cites="baertschi-mulligan:2001">Baertschi
# and Mulligan (<a href="#ref-c1-baertschi-mulligan:2001" role="doc-biblioref">2001a</a>)</span></p>
# <p><span class="citation" data-cites="baertschi-mulligan:2001a">Baertschi and Mulligan (<a href="#ref-c1-baertschi-mulligan:2001a" role="doc-biblioref">2001b</a>)</span></p>
# <p><span class="citation" data-cites="cometti-mulligan:2001">Cometti and
# Mulligan (<a href="#ref-c1-cometti-mulligan:2001" role="doc-biblioref">2001</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2001">Mulligan, K. (<a href="#ref-c1-mulligan_k:2001" role="doc-biblioref">2001a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2001a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2001a" role="doc-biblioref">2001b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2001b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2001b" role="doc-biblioref">2001c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2001c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2001c" role="doc-biblioref">2001d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2001d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2001d" role="doc-biblioref">2001e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2002">Mulligan, K. (<a href="#ref-c1-mulligan_k:2002" role="doc-biblioref">2002a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2002a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2002a" role="doc-biblioref">2002b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2002b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2002b" role="doc-biblioref">2002c</a>)</span></p>
# <p><span class="citation" data-cites="engel_p-mulligan:2003">Engel and
# Mulligan (<a href="#ref-c1-engel_p-mulligan:2003" role="doc-biblioref">2003</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003" role="doc-biblioref">2003a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003a" role="doc-biblioref">2003b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003b" role="doc-biblioref">2003c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003c" role="doc-biblioref">2003d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003d" role="doc-biblioref">2003e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2003e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2003e" role="doc-biblioref">2003f</a>)</span></p>
# <p><span class="citation" data-cites="hochberg-mulligan:2004">Hochberg
# and Mulligan (<a href="#ref-c1-hochberg-mulligan:2004" role="doc-biblioref">2004</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2004">Mulligan, K. (<a href="#ref-c1-mulligan_k:2004" role="doc-biblioref">2004a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2004a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2004a" role="doc-biblioref">2004b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2004b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2004b" role="doc-biblioref">2004c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2004c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2004c" role="doc-biblioref">2004d</a>)</span></p>
# <p><span class="citation" data-cites="smith_ba-mulligan:2005">Smith and
# Mulligan (<a href="#ref-c1-smith_ba-mulligan:2005" role="doc-biblioref">2005</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:2006">Mulligan,
# K., Simons and Smith (<a href="#ref-c1-mulligan_k-etal:2006" role="doc-biblioref">2006</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006" role="doc-biblioref">2006a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006a" role="doc-biblioref">2006b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006b" role="doc-biblioref">2006c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006c" role="doc-biblioref">2006d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006d" role="doc-biblioref">2006e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2006e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2006e" role="doc-biblioref">2006f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2007">Mulligan, K. (<a href="#ref-c1-mulligan_k:2007" role="doc-biblioref">2007a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2007b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2007b" role="doc-biblioref">2007b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2007c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2007c" role="doc-biblioref">2007c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2008">Mulligan, K. (<a href="#ref-c1-mulligan_k:2008" role="doc-biblioref">2008a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2008a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2008a" role="doc-biblioref">2008b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2008b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2008b" role="doc-biblioref">2008c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-westerhoff:2009">Mulligan, K. and Westerhoff (<a href="#ref-c1-mulligan_k-westerhoff:2009" role="doc-biblioref">2009a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-westerhoff:2009a">Mulligan, K. and Westerhoff (<a href="#ref-c1-mulligan_k-westerhoff:2009a" role="doc-biblioref">2009b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009" role="doc-biblioref">2009a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009a" role="doc-biblioref">2009b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009b" role="doc-biblioref">2009c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009c" role="doc-biblioref">2009d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009d" role="doc-biblioref">2009e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009e" role="doc-biblioref">2009f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009f">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009f" role="doc-biblioref">2009g</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2009g">Mulligan, K. (<a href="#ref-c1-mulligan_k:2009g" role="doc-biblioref">2009h</a>)</span></p>
# <p><span class="citation" data-cites="baertschi-mulligan:2010">Baertschi
# and Mulligan (<a href="#ref-c1-baertschi-mulligan:2010" role="doc-biblioref">2010a</a>)</span></p>
# <p><span class="citation" data-cites="baertschi-mulligan:2010a">Baertschi and Mulligan (<a href="#ref-c1-baertschi-mulligan:2010a" role="doc-biblioref">2010b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2010">Mulligan, K. (<a href="#ref-c1-mulligan_k:2010" role="doc-biblioref">2010a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2010a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2010a" role="doc-biblioref">2010b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2010b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2010b" role="doc-biblioref">2010c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:2011">Mulligan,
# K., Simons and Smith (<a href="#ref-c1-mulligan_k-etal:2011" role="doc-biblioref">2011</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2011">Mulligan, K. (<a href="#ref-c1-mulligan_k:2011" role="doc-biblioref">2011a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2011a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2011a" role="doc-biblioref">2011b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2011b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2011b" role="doc-biblioref">2011c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-scherer:2012">Mulligan,
# K. and Scherer (<a href="#ref-c1-mulligan_k-scherer:2012" role="doc-biblioref">2012a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-scherer:2012a">Mulligan, K. and Scherer (<a href="#ref-c1-mulligan_k-scherer:2012a" role="doc-biblioref">2012b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span></p>
# <p><span class="citation" data-cites="gerrans-mulligan:2013">Gerrans and
# Mulligan (<a href="#ref-c1-gerrans-mulligan:2013" role="doc-biblioref">2013</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:2013">Mulligan,
# K., Kijania-Placek and Placek (<a href="#ref-c1-mulligan_k-etal:2013" role="doc-biblioref">2013a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-etal:2013a">Mulligan,
# K., Kijania-Placek and Placek (<a href="#ref-c1-mulligan_k-etal:2013a" role="doc-biblioref">2013b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013a" role="doc-biblioref">2013a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013c" role="doc-biblioref">2013b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013e" role="doc-biblioref">2013c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013f">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013f" role="doc-biblioref">2013d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013g">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013g" role="doc-biblioref">2013e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2014">Mulligan, K. (<a href="#ref-c1-mulligan_k:2014" role="doc-biblioref">2014a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2014a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2014a" role="doc-biblioref">2014b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2015">Mulligan, K. (<a href="#ref-c1-mulligan_k:2015" role="doc-biblioref">2015a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2015a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2015a" role="doc-biblioref">2015b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2015c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2015c" role="doc-biblioref">2015c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2015d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2015d" role="doc-biblioref">2015d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2015e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2015e" role="doc-biblioref">2015e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2016">Mulligan, K. (<a href="#ref-c1-mulligan_k:2016" role="doc-biblioref">2016a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2016a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2016a" role="doc-biblioref">2016b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2016b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2016b" role="doc-biblioref">2016c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2016c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2016c" role="doc-biblioref">2016d</a>)</span></p>
# <p><span class="citation" data-cites="cesalli-mulligan:2017">Cesalli and
# Mulligan (<a href="#ref-c1-cesalli-mulligan:2017" role="doc-biblioref">2017</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017" role="doc-biblioref">2017a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017a">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017a" role="doc-biblioref">2017b</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017b">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017b" role="doc-biblioref">2017c</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017c">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017c" role="doc-biblioref">2017d</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017d" role="doc-biblioref">2017e</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2017e">Mulligan, K. (<a href="#ref-c1-mulligan_k:2017e" role="doc-biblioref">2017f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2018">Mulligan, K. (<a href="#ref-c1-mulligan_k:2018" role="doc-biblioref">2018</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2019">Mulligan, K. (<a href="#ref-c1-mulligan_k:2019" role="doc-biblioref">2019</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2020">Mulligan, K. (<a href="#ref-c1-mulligan_k:2020" role="doc-biblioref">2020</a>)</span></p>
# <p><span class="citation" data-cites="massin-mulligan:2021">Massin and
# Mulligan (<a href="#ref-c1-massin-mulligan:2021" role="doc-biblioref">2021</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2021">Mulligan, K. (<a href="#ref-c1-mulligan_k:2021" role="doc-biblioref">2021</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2022">Mulligan, K. (<a href="#ref-c1-mulligan_k:2022" role="doc-biblioref">2022</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:2013d">Mulligan, K. (<a href="#ref-c1-mulligan_k:2013d" role="doc-biblioref">2013f</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k-woodruff:unpub">Mulligan, K. and Woodruff Smith
# (<a href="#ref-c1-mulligan_k-woodruff:unpub" role="doc-biblioref">n.d.</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:unpub">Mulligan, K. (<a href="#ref-c1-mulligan_k:unpub" role="doc-biblioref">n.d.a</a>)</span></p>
# <p><span class="citation" data-cites="mulligan_k:unpub-a">Mulligan, K.
# (<a href="#ref-c1-mulligan_k:unpub-a" role="doc-biblioref">n.d.b</a>)</span></p>
# <h1 class="unnumbered" id="sec:c1-references">References</h1><div class="references csl-bib-body hanging-indent" data-entry-spacing="0" id="c1-refs" role="list">
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2001" role="listitem">
# <span class="smallcaps">Baertschi</span>, Bernard and <span class="smallcaps">Mulligan</span>, Kevin, eds. 2001a. <em><span>Les
# nationalismes</span></em>. <span><span>É</span>thique et philosophie
# morale</span>. Paris: Presses Universitaires de France.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2001a" role="listitem">
# —. 2001b. <span>“<span>Introduction</span>.”</span> in <em><span>Les
# nationalismes</span></em>, edited by Bernard <span class="smallcaps">Baertschi</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 3–11. <span><span>É</span>thique
# et philosophie morale</span>. Paris: Presses Universitaires de France.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2010" role="listitem">
# —, eds. 2010a. <em><span>Nationalismele</span></em>. Bucarest: Nemira.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2010a" role="listitem">
# —. 2010b. <span>“<span>Introducere</span>.”</span> in
# <em><span>Nationalismele</span></em>, edited by Bernard <span class="smallcaps">Baertschi</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 8–14. Bucarest: Nemira.
# </div>
# <div class="csl-entry" id="ref-c1-cesalli-mulligan:2017" role="listitem">
# <span class="smallcaps">Cesalli</span>, Laurent and <span class="smallcaps">Mulligan</span>, Kevin. 2017. <span>“<span class="nocase">Marty and Brentano</span>.”</span> in <em><span class="nocase">The Routledge Handbook of Franz Brentano and the Brentano
# School</span></em>, edited by Uriah <span class="smallcaps">Kriegel</span>, pp. 251–263. <span class="nocase">Routledge Handbooks in Philosophy</span>. London:
# Routledge.
# </div>
# <div class="csl-entry" id="ref-c1-cometti-mulligan:2001" role="listitem">
# <span class="smallcaps">Cometti</span>, Jean-Pierre and <span class="smallcaps">Mulligan</span>, Kevin, eds. 2001. <em><span>La
# philosophie autrichienne de Bolzano <span>à</span> Musil. Histoire et
# actualit<span>é</span> (Actes du colloque de 1997 <span>à</span>
# Cerisy-la-Salle)</span></em>. <span>Probl<span>è</span>mes &amp;
# Controverses</span>. Paris: Librairie philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-engel_p-mulligan:2003" role="listitem">
# <span class="smallcaps">Engel</span>, Pascal and <span class="smallcaps">Mulligan</span>, Kevin. 2003. <span>“<span>Normes
# <span>é</span>thiques et normes cognitives</span>.”</span>
# <em>Cit<span>é</span>s</em> 15: 171–186.
# </div>
# <div class="csl-entry" id="ref-c1-frechette:2015a" role="listitem">
# <span class="smallcaps">Fréchette</span>, Guillaume. 2015.
# <span>“<span>Le moment normatif dans la philosophie austro-allemande
# [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K.
# (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 375–384.
# </div>
# <div class="csl-entry" id="ref-c1-garrett_bj-mulligan:1993" role="listitem">
# <span class="smallcaps">Garrett</span>, Brian John and <span class="smallcaps">Mulligan</span>, Kevin, eds. 1993. <em><span class="nocase">Themes from Wittgenstein</span></em>. <span class="nocase">Working Papers in Philosophy</span> n. 4. Canberra: RSSS
# Australasian National University.
# </div>
# <div class="csl-entry" id="ref-c1-gerrans-mulligan:2013" role="listitem">
# <span class="smallcaps">Gerrans</span>, Philip and <span class="smallcaps">Mulligan</span>, Kevin. 2013.
# <span>“<span>Immaginazione, <em>default thinking</em> e
# incorporamento</span>.”</span> <em>Rivista di Estetica</em> 53: 55–87.
# </div>
# <div class="csl-entry" id="ref-c1-hochberg-mulligan:2004" role="listitem">
# <span class="smallcaps">Hochberg</span>, Herbert and <span class="smallcaps">Mulligan</span>, Kevin, eds. 2004. <em><span class="nocase">Relations and Predicates</span></em>.
# <span>Philosophische Analyse / Philosophical Analysis</span> n. 11.
# Heusenstamm b. Frankfurt: Ontos Verlag.
# </div>
# <div class="csl-entry" id="ref-c1-husserl_e:1984" role="listitem">
# <span class="smallcaps">Husserl</span>, Edmund. 1984. <em><span>Logische
# Untersuchungen. Zweiter Teil. Untersuchungen zur
# Ph<span>ä</span>nomenologie und Theorie der Erkenntnis</span></em>.
# <span>Husserliana</span> n. 19. Den Haag: Martinus Nijhoff Publishers.
# <span>Herausgegeben von Ursula Panzer</span>.
# </div>
# <div class="csl-entry" id="ref-c1-kuenne_w:2003" role="listitem">
# <span class="smallcaps">Künne</span>, Wolfgang. 2003. <em><span class="nocase">Conceptions of Truth</span></em>. Oxford: Oxford
# University Press, doi:<a href="https://doi.org/10.1093/0199241317.001.0001">10.1093/0199241317.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-leyvraz-mulligan:1993" role="listitem">
# <span class="smallcaps">Leyvraz</span>, Jean-Pierre and <span class="smallcaps">Mulligan</span>, Kevin, eds. 1993.
# <em><span>Wittgenstein analys<span>é</span></span></em>.
# N<span>î</span>mes: <span>É</span>ditions Jacqueline Chambon.
# </div>
# <div class="csl-entry" id="ref-c1-massin-mulligan:2021" role="listitem">
# <span class="smallcaps">Massin</span>, Olivier and <span class="smallcaps">Mulligan</span>, Kevin. 2021.
# <em><span>D<span>é</span>crire. La psychologie de Franz
# Brentano</span></em>. <span>Analyse et philosophie</span>. Paris:
# Librairie philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-moore_aw:2012" role="listitem">
# <span class="smallcaps">Moore</span>, Adrian W. 2012. <em><span class="nocase">The Evolution of Modern Metaphysics: Making Sense of
# Things</span></em>. <span class="nocase">The Evolution of Modern
# Philosophy</span>. Cambridge: Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1980" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin. 1980. <span>“<span class="nocase">Structure and Rules in Wittgenstein and
# Husserl</span>.”</span> in <em><span class="nocase">Proceedings of the
# 4th International Wittgenstein Symposium: Language, Logic, and
# Philosophy</span></em>, edited by Rudolf <span class="smallcaps">Haller</span> and Wolfgang <span class="smallcaps">Grassl</span>, pp. 461–464. <span class="nocase">Schriftenreihe der <span>Ö</span>sterreichischen Ludwig
# Wittgenstein Gesellschaft</span> n. 4. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1981" role="listitem">
# —. 1981. <span>“<span class="nocase">Philosophy, Animality and Justice:
# Kleist, Kafka, Weininger and Wittgenstein</span>.”</span> in
# <em>Proceedings of the Aristotelian Society, Supplementary Volume</em>,
# volume 55, pp. 293–311.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983" role="listitem">
# —. 1983a. <span>“<span class="nocase">Constituency and Dependence in
# Language</span>.”</span> in <em><span class="nocase">Parts &amp;
# Wholes. An Inventory of Present Thinking about Parts and
# Wholes</span></em>, volume I, edited by Pehr <span class="smallcaps">Sällström</span>, pp. 75–89. Stockholm:
# Forsknings<span>å</span>dsn<span>ä</span>men.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983a" role="listitem">
# —. 1983b. <span>“<span class="nocase">Colours and
# Complexity</span>.”</span> in <em><span class="nocase">Parts &amp;
# Wholes. An Inventory of Present Thinking about Parts and
# Wholes</span></em>, volume I, edited by Pehr <span class="smallcaps">Sällström</span>, pp. 43–50. Stockholm:
# Forsknings<span>å</span>dsn<span>ä</span>men.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983b" role="listitem">
# —. 1983c. <span>“<span>Spinoza on Necessary Existential
# Determination</span>.”</span> in <em><span>Leibniz. Werk und
# Wirkung. IV. Internationaler
# Leibniz-Kongress. Vortr<span>ä</span>ge. Hannover, 14. bis 19. November
# 1983</span></em>, edited by <span class="smallcaps">G.W.-Leibniz-Gesellschaft</span>, pp. 532–539.
# Hannover: Leibniz Gesellschaft.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1985" role="listitem">
# —. 1985. <span>“<span class="nocase"> <span>‘Wie die Sachen sich
# zueinander verhalten’</span>: Inside and Outside the
# Tractatus</span>.”</span> <em>Teoria</em> 5(2): 145–174.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1986" role="listitem">
# —. 1986. <span>“<span class="nocase">Exactness, Description and
# Variation – How Austrian Analytic Philosophy was Done</span>.”</span> in
# <em><span class="nocase">From Bolzano to Wittgenstein: The Tradition of
# Austrian Philosophy</span></em>, edited by János Kristóf <span class="smallcaps">Nyı́ri</span>, pp. 86–97. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1987" role="listitem">
# —, ed. 1987a. <em><span class="nocase">Speech Act and Sachverhalt:
# Reinach and the Foundations of Realist Phenomenology</span></em>. Den
# Haag: Martinus Nijhoff Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1987a" role="listitem">
# —. 1987b. <span>“<span class="nocase">Promisings and other Social Acts:
# Their Constituents and Structure</span>.”</span> in <em><span class="nocase">Speech Act and Sachverhalt: Reinach and the Foundations
# of Realist Phenomenology</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 29–90. Den Haag: Martinus Nijhoff
# Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988" role="listitem">
# —. 1988a. <span>“<span class="nocase">Judgings: Their Parts and
# Counterparts</span>.”</span> <em>Topoi</em> 2(suppl.): 117–148.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988a" role="listitem">
# —. 1988b. <span>“<span class="nocase">On the Notion of Structure: B<span class="nocase">ü</span>hler’s Linguistic and Psychological
# Examples</span>.”</span> in, edited by Achim <span class="smallcaps">Eschbach</span>, pp. 203–226. <span>Viennese Heritage
# / Wiener Erbe</span> n. 2. Amsterdam: John Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988b" role="listitem">
# —. 1988c. <span>“<span class="nocase">Seeing as and Assimilative
# Perception</span>.”</span> <em>Brentano Studien</em> 1: 129–152.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988c" role="listitem">
# —. 1988d. <span>“<span>La m<span>é</span>taphysique</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1989" role="listitem">
# —. 1989. <span>“<span class="nocase">The Expression of Exactness: Ernst
# Mach, the Brentanists and the Ideal of Clarity</span>.”</span> in
# <em><span class="nocase">Decadence and Innovation. Austro-Hungarian Life
# and Art at the Turn of the Century</span></em>, edited by Robert <span class="smallcaps">Pynsent</span>, pp. 33–42. London: Weidenfeld;
# Nicolson.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990" role="listitem">
# —, ed. 1990a. <em><span class="nocase">Mind, Meaning and Metaphysics:
# The Philosophy and Theory of Language of Anton Marty</span></em>. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990a" role="listitem">
# —. 1990b. <span>“<span class="nocase">Criteria and
# Indication</span>.”</span> in <em><span class="nocase">Proceedings of
# the 14th International Wittgenstein Symposium: Wittgenstein – Towards a
# Re-Evaluation. Volume II</span></em>, edited by Rudolf <span class="smallcaps">Haller</span> and Johannes L. <span class="smallcaps">Brandl</span>, pp. 94–105. <span class="nocase">Schriftenreihe der <span>Ö</span>sterreichischen Ludwig
# Wittgenstein Gesellschaft</span> n. 19/2. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990b" role="listitem">
# —. 1990c. <span>“<span>Genauigkeit und Geschw<span>ä</span>tz – Glossen
# zu einem paradigmatischen Gegensatz in der Philosophie</span>.”</span>
# in <em><span>Wien – Paradigmen der Moderne</span></em>, edited by H.
# <span class="smallcaps">Bachmaier</span>, pp. 209–236. Amsterdam: John
# Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990c" role="listitem">
# —. 1990d. <span>“<span class="nocase">Marty’s Philosophical
# Grammar</span>.”</span> in <em><span class="nocase">Mind, Meaning and
# Metaphysics: The Philosophy and Theory of Language of Anton
# Marty</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 11–28. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990d" role="listitem">
# —. 1990e. <span>“<span class="nocase">Husserl on States of Affairs in
# the <em>Logical Investigations</em></span>.”</span>
# <em>Epistemologia. An International Review for the Philosophy of
# Science</em> 12: 207–234.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990e" role="listitem">
# —. 1990f. <span>“<span>Las situaciones objetivas en las
# <em>Investigaciones Logicas</em> de Edmundo Husserl</span>.”</span>
# <em>Revista de filosofia</em> 3(3): 23–49.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991" role="listitem">
# —. 1991a. <span>“<span class="nocase">Introduction: On the History of
# Continental Philosophy</span>.”</span> <em>Topoi</em> 10(2): 115–120.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991a" role="listitem">
# —. 1991b. <span>“<span class="nocase">Colours, Corners and Complexity:
# Meinong and Wittgenstein on Some Internal Relations</span>.”</span> in
# <em><span class="nocase">Existence and Explanation. Essays presented in
# Honor of Karel Lambert</span></em>, edited by Wolfgang <span class="smallcaps">Spohn</span>, Bas C. van <span class="smallcaps">Fraassen</span>, and Brian <span class="smallcaps">Skyrms</span>, pp. 77–101. <span class="nocase">The
# University of Western Ontario Series in Philosophy of Science</span>
# n. 49. Dordrecht: Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991b" role="listitem">
# —. 1991c. <span>“<span class="nocase">How Not to Read: Derrida on
# Husserl</span>.”</span> <em>Topoi</em> 10(2): 199–208.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1992" role="listitem">
# —, ed. 1992. <em><span class="nocase">Language, Truth and
# Ontology</span></em>. <span>Philosophical Studies Series</span> n. 51.
# Dordrecht: D. Reidel Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993" role="listitem">
# —. 1993a. <span>“<span>Internal Relations</span>.”</span> in
# <em><span>1992 ANU Metaphysics Conference</span></em>, edited by Brian
# ...
# Identit<span>é</span>,structure et
# m<span>é</span>taontologie</span></em>, edited by Frédéric <span class="smallcaps">Nef</span>, Yann <span class="smallcaps">Schmitt</span>, and Luc <span class="smallcaps">Schneider</span>. <span>Textes
# cl<span>é</span>s</span>. Paris: Librairie philosophique Jean Vrin.
# <span>French translation of <span class="citation" data-cites="mulligan_k:1998">Mulligan, K. (<a href="#ref-c1-mulligan_k:1998" role="doc-biblioref">1998a</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017d" role="listitem">
# —. 2017e. <span>“<span class="nocase">Intentionality, Reasons and
# Motives</span>.”</span> in <em><span class="nocase">Intentionality and
# Action</span></em>, edited by Jesús <span class="smallcaps">Padilla
# Gálvez</span> and Margit <span class="smallcaps">Gaffal</span>, pp.
# 9–22. <span>Aporia</span> n. 10. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017e" role="listitem">
# —. 2017f. <span>“<span>Panentheistic Dualisms, Chaos and Values. The
# Metaphysics of Ehrenfels and Scheler</span>.”</span> in
# <em><span>Christian von Ehrenfels: Philosophie – Gestalttheorie –
# Kunst. <span>Ö</span>sterreichische Ideengeschichte im Fin de
# Si<span>è</span>cle</span></em>, edited by Ulf <span class="smallcaps">Hoefer</span> and Jutta <span class="smallcaps">Valent</span>, pp. 69–82. <span>Meinong Studies /
# Meinong Studien</span> n. 8. Berlin: de Gruyter, doi:<a href="https://doi.org/10.1515/9783110518306-005">10.1515/9783110518306-005</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2018" role="listitem">
# —. 2018. <span>“<span class="nocase">Early Analytic Philosophy’s
# Austrian Dimensions</span>.”</span> in <em><span class="nocase">Eva
# Picardi on Language, Analysis and History</span></em>, edited by
# Annalisa <span class="smallcaps">Coliva</span>, Paolo <span class="smallcaps">Leonardi</span>, and Sebastiano <span class="smallcaps">Moruzzi</span>, pp. 7–30. London: Palgrave Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2019" role="listitem">
# —. 2019. <span>“<span class="nocase">Modes of Being and the
# Mind</span>.”</span> in <em><span class="nocase">Quo Vadis, Metaphysics?
# Essays in Honor of Peter van Inwagen</span></em>, edited by Mirosław
# <span class="smallcaps">Szatkowski</span>, pp. 183–202.
# <span>Philosophical Analysis</span> n. 81. Berlin: de Gruyter, doi:<a href="https://doi.org/10.1515/9783110664812">10.1515/9783110664812</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2020" role="listitem">
# —. 2020. <span>“<span>Austro-German Phenomenologists</span>.”</span> in
# <em><span class="nocase">The Routledge Handbook of Metaphysical
# Grounding</span></em>, edited by Michael J. <span class="smallcaps">Raven</span>, pp. 90–101. <span class="nocase">Routledge Handbooks in Philosophy</span>. London:
# Routledge, doi:<a href="https://doi.org/10.4324/9781351258845">10.4324/9781351258845</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2021" role="listitem">
# —. 2021. <span>“<span class="nocase">On Being Guided, Signals and Rules:
# From B<span class="nocase">ü</span>hler to Wittgenstein</span>.”</span>
# in <em><span class="nocase">Philosophy of Language in the Brentano
# School. Reassessing the Brentanian Legacy</span></em>, edited by Arnaud
# <span class="smallcaps">Dewalque</span>, Charlotte <span class="smallcaps">Gauvry</span>, and Sébastien <span class="smallcaps">Richard</span>, pp. 299–315. London: Palgrave
# Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2022" role="listitem">
# —. 2022. <span>“<span class="nocase">Logic, Logical Norms, and
# (Normative) Grounding</span>.”</span> in <em><span class="nocase">Bolzano’s Philosophy of Grounding. Translations and
# Studies</span></em>, edited by Stefan <span class="smallcaps">Roski</span> and Benjamin Sebastian <span class="smallcaps">Schnieder</span>, pp. 244–275. Oxford: Oxford
# University Press, doi:<a href="https://doi.org/10.1093/oso/9780192847973.001.0001">10.1093/oso/9780192847973.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:unpub" role="listitem">
# —. n.d.a. <span>“<span class="nocase">The Roots of Reism</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:unpub-a" role="listitem">
# —. n.d.b. <span>“<span class="nocase">Austro-German Essence and
# Modality</span>.”</span> <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:2013" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin, <span class="smallcaps">Kijania-Placek</span>, Katarzyna and <span class="smallcaps">Placek</span>, Tomasz, eds. 2013a. <em><span class="nocase">The History and Philosophy of Polish Logic, Essays in
# Honour of Jan Wole<span class="nocase">ń</span>ski</span></em>. <span class="nocase">History of Analytic Philosophy</span>. Basingstoke,
# Hampshire: Palgrave Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:2013a" role="listitem">
# —. 2013b. <span>“<span class="nocase">Introduction: The History and
# Philosophy of Polish Logic: Some Basic Thoughts</span>.”</span> in
# <em><span class="nocase">The History and Philosophy of Polish Logic,
# Essays in Honour of Jan Wole<span class="nocase">ń</span>ski</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, Katarzyna <span class="smallcaps">Kijania-Placek</span>, and Tomasz <span class="smallcaps">Placek</span>, pp. 1–11. <span class="nocase">History
# of Analytic Philosophy</span>. Basingstoke, Hampshire: Palgrave
# Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-roth:1993" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Roth</span>, Robert J., eds. 1993. <em><span>Regards
# sur Bentham et l’utilitarisme (Actes du colloque organis<span>é</span>
# <span>à</span> Gen<span>è</span>ve les 23 et 24 novembre
# 1990)</span></em>. <span>Recherches et Rencontres</span> n. 4.
# Gen<span>è</span>ve: Droz.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-rug:1985" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Rug</span>, Reinhild. 1985. <span>“<span>Trieb und
# Theorie: Bemerkungen zu Ehrenfels und Freud</span>.”</span> in
# <em><span>Leben und Werk von Christian von Ehrenfels</span></em>, edited
# by Reinhard <span class="smallcaps">Fabian</span>, pp. 214–246.
# Amsterdam: Rodopi.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-scherer:2012" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Scherer</span>, Klaus R. 2012a. <span>“<span class="nocase">Toward a Working Definition of Emotion</span>.”</span>
# <em>Emotion Review</em> 4(4): 345–357.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-scherer:2012a" role="listitem">
# —. 2012b. <span>“<span class="nocase">Definitions Come in Many Kinds:
# Reply to Comments</span>.”</span> <em>Emotion Review</em> 4(4): 389–390.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-schuhmann:1990" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Schuhmann</span>, Karl. 1990. <span>“<span class="nocase">Two Letters from Marty to Husserl</span>.”</span> in
# <em><span class="nocase">Mind, Meaning and Metaphysics: The Philosophy
# and Theory of Language of Anton Marty</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 225–236. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:1984" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin, <span class="smallcaps">Simons</span>, Peter M. and <span class="smallcaps">Smith</span>, Barry. 1984.
# <span>“<span>Truth-Makers</span>.”</span> <em>Philosophy and
# Phenomenological Research</em> 44(3): 287–321.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:1987" role="listitem">
# —. 1987. <span>“<span>Wahrmacher</span>.”</span> in <em><span>Der
# Wahrheitsbegriff: neue Erkl<span>ä</span>rungsversuche</span></em>,
# edited by Lorenz Bruno <span class="smallcaps">Puntel</span>, pp.
# 210–255. <span>Wege der Forschung</span> n. 636. Darmstadt:
# Wissenschaftliche Buchgesellschaft. <span>Translation of <span class="citation" data-cites="mulligan_k-etal:1984">Mulligan, K., Simons
# and Smith (<a href="#ref-c1-mulligan_k-etal:1984" role="doc-biblioref">1984</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:2006" role="listitem">
# —. 2006. <span>“<span class="nocase">What’s Wrong with Contemporary
# Philosophy?</span>”</span> <em>Topoi</em> 25: 63–67.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:2011" role="listitem">
# —. 2011. <span>“<span>V<span>é</span>rifacteurs</span>.”</span>
# <em><span>É</span>tudes de philosophie</em> 9–10: 104–138.
# <span>Translation of <span class="citation" data-cites="mulligan_k-etal:1984">Mulligan, K., Simons and Smith (<a href="#ref-c1-mulligan_k-etal:1984" role="doc-biblioref">1984</a>)</span> by B. Langlet and
# J.-Fr. Rosecchi</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1983" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Smith</span>, Barry. 1983. <span>“<span class="nocase">Framework for Formal Ontology</span>.”</span>
# <em>Topoi</em> 2: 73–86.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1984" role="listitem">
# —. 1984. <span>“<span class="nocase">Traditional vs. Analytic
# Philosophy</span>.”</span> <em>Grazer Philosophische Studien</em> 21:
# 193–202.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1985" role="listitem">
# —. 1985. <span>“<span class="nocase">Franz Brentano on the Ontology of
# Mind</span>.”</span> <em>Philosophy and Phenomenological Research</em>
# 45(4): 627–644.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986" role="listitem">
# —. 1986a. <span>“<span class="nocase">A Relational Theory of the
# Act</span>.”</span> <em>Topoi</em> 5(2): 115–130.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986a" role="listitem">
# —. 1986b. <span>“<span class="nocase">A Husserlian Theory of
# Indexicality</span>.”</span> <em>Grazer Philosophische Studien</em> 28:
# 133–163. <span> <span>“Philosophische Aufs<span>ä</span>tze zu Ehren von
# Roderick M. Chisholm,”</span> ed. by Marian David and Leopold
# Stubenberg</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986b" role="listitem">
# —. 1986c. <span>“<span class="nocase">Husserl’s <em>Logical
# Investigations</em> [Review of <span class="citation" data-cites="husserl_e:1984">Husserl (<a href="#ref-c1-husserl_e:1984" role="doc-biblioref">1984</a>)</span>]</span>.”</span> <em>Grazer
# Philosophische Studien</em> 27: 199–207.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-westerhoff:2009" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Westerhoff</span>, Armin, eds. 2009a. <em><span>Robert
# Musil – Ironie, Satire, falsche Gef<span>ü</span>hle</span></em>.
# Paderborn: Mentis Verlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-westerhoff:2009a" role="listitem">
# —. 2009b. <span>“<span>Statt einer Einleitung: Drei Stichworte und zwei
# Kontexte zu Robert Musil</span>.”</span> in <em><span>Robert Musil –
# Ironie, Satire, falsche Gef<span>ü</span>hle</span></em>, edited by
# Kevin <span class="smallcaps">Mulligan</span> and Armin <span class="smallcaps">Westerhoff</span>, pp. 7–11. Paderborn: Mentis Verlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-woodruff:unpub" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Woodruff Smith</span>, David. n.d. <span>“<span class="nocase">Abstraction, Relations and Perception</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_r-etal:1997" role="listitem">
# <span class="smallcaps">Mulligan</span>, R., <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Juillerat</span>, Anne-Claude. 1997. <span>“<span>La
# m<span>é</span>moire affective: Le cas de la douleur</span>.”</span>
# <em>Cahiers psychiatriques</em> 23: 157–161.
# </div>
# <div class="csl-entry" id="ref-c1-philie:2015" role="listitem">
# <span class="smallcaps">Philie</span>, Patrice. 2015.
# <span>“<span>Wittgenstein et Ortega sur les lois logiques de base [sur
# <span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 391–399.
# </div>
# <div class="csl-entry" id="ref-c1-plourde_j:2015" role="listitem">
# <span class="smallcaps">Plourde</span>, Jimmy. 2015.
# <span>“<span>Autonomie de la logique et fondements des
# modalit<span>é</span>s <em>de re</em> syntaxique et <em>de dicto</em>
# sur la modalit<span>é</span> <em>de re</em> ontique [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 367–373.
# </div>
# <div class="csl-entry" id="ref-c1-seron:2015a" role="listitem">
# <span class="smallcaps">Seron</span>, Denis. 2015. <span>“<span>Les
# couleurs, la ph<span>é</span>nom<span>é</span>nologie et la grammaire
# [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K.
# (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 385–389.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1982" role="listitem">
# <span class="smallcaps">Smith</span>, Barry and <span class="smallcaps">Mulligan</span>, Kevin. 1982. <span>“<span class="nocase">Pieces of a Theory</span>.”</span> in <em><span class="nocase">Parts and Moments – Studies in Logic and Formal
# Ontology</span></em>, edited by Barry <span class="smallcaps">Smith</span>, pp. 15–109. <span class="nocase">Analytica: Investigations in Logic, Ontology, and the
# Philosophy of Language</span>. M<span>ü</span>nchen: Philosophia Verlag,
# doi:<a href="https://doi.org/10.2307/j.ctv2x8v896">10.2307/j.ctv2x8v896</a>.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1983" role="listitem">
# —. 1983. <span>“<span class="nocase">Framework for Formal
# Ontology</span>.”</span> <em>Topoi</em> 2: 73–85.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1985" role="listitem">
# —. 1985. <span>“<span>Mach und Ehrenfels: <span>Ü</span>ber
# Gestaltqualit<span>ä</span>ten und das Problem der
# Abh<span>ä</span>ngigkeit</span>.”</span> in <em><span>Leben und Werk
# von Christian von Ehrenfels</span></em>, edited by Reinhard <span class="smallcaps">Fabian</span>, pp. 85–111. Amsterdam: Rodopi.
# <span>Expanded English version: <span class="citation" data-cites="smith_ba-mulligan:1988">Smith and Mulligan (<a href="#ref-c1-smith_ba-mulligan:1988" role="doc-biblioref">1988</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1988" role="listitem">
# —. 1988. <span>“<span class="nocase">Mach and Ehrenfels: The Foundations
# of Gestalt Theory</span>.”</span> in <em><span class="nocase">Foundations of Gestalt Theory</span></em>, edited by
# Barry <span class="smallcaps">Smith</span>, pp. 124–157.
# <span>Philosophia Resources Library</span>. M<span>ü</span>nchen:
# Philosophia Verlag. <span>Expanded English version of <span class="citation" data-cites="smith_ba-mulligan:1985">Smith and Mulligan
# (<a href="#ref-c1-smith_ba-mulligan:1985" role="doc-biblioref">1985</a>)</span></span>, doi:<a href="https://doi.org/10.2307/j.ctv2x8v91j">10.2307/j.ctv2x8v91j</a>.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:2005" role="listitem">
# —. 2005. <span>“<span>Mach si Ehrenfels. Fundamentele teoriei
# gestaltiste</span>.”</span> in <em><span>Filosofia
# Austriaca</span></em>, edited by Constantin <span class="smallcaps">Stoenescu</span> and Ion <span class="smallcaps">Tansescu</span>, pp. 262–298. Bucarest: Pelican.
# </div>
# </div>
# </section>
# </body>
# </html>
# >

# %%
from bs4 import Tag


divs_all = soup.find_all('div')
divs = [div for div in divs_all if isinstance(div, Tag)]
print(divs[-1])
# Out:
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:2005" role="listitem">
# —. 2005. <span>“<span>Mach si Ehrenfels. Fundamentele teoriei
# gestaltiste</span>.”</span> in <em><span>Filosofia
# Austriaca</span></em>, edited by Constantin <span class="smallcaps">Stoenescu</span> and Ion <span class="smallcaps">Tansescu</span>, pp. 262–298. Bucarest: Pelican.
# </div>

# %%
divs[-1].get('id')
# Out:
# 'ref-c1-smith_ba-mulligan:2005'

# %%
def get_id(div) -> str:
    bs_getter = div.get('id')
    match bs_getter:
        case None:
            return ""
        case _:
            return bs_getter.__str__()

# %%
bib_keys_s = "mulligan_k:1980,mulligan_k:1981,smith_ba-mulligan:1982,mulligan_k-smith:1983,mulligan_k:1983,mulligan_k:1983a,mulligan_k:1983b,smith_ba-mulligan:1983,mulligan_k-etal:1984,mulligan_k-smith:1984,mulligan_k-rug:1985,mulligan_k-smith:1985,mulligan_k:1985,smith_ba-mulligan:1985,mulligan_k-smith:1986,mulligan_k-smith:1986a,mulligan_k-smith:1986b,mulligan_k:1986,mulligan_k-etal:1987,mulligan_k:1987,mulligan_k:1987a,mulligan_k:1988,mulligan_k:1988a,mulligan_k:1988b,mulligan_k:1988c,smith_ba-mulligan:1988,mulligan_k:1989,mulligan_k-schuhmann:1990,mulligan_k:1990,mulligan_k:1990a,mulligan_k:1990b,mulligan_k:1990c,mulligan_k:1990d,mulligan_k:1990e,mulligan_k:1991,mulligan_k:1991a,mulligan_k:1991b,mulligan_k:1992,garrett_bj-mulligan:1993,leyvraz-mulligan:1993,mulligan_k-roth:1993,mulligan_k:1993,mulligan_k:1993a,mulligan_k:1993b,mulligan_k:1993c,mulligan_k:1995,mulligan_k:1995a,mulligan_k:1995b,mulligan_k:1996,mulligan_k:1997,mulligan_k:1997a,mulligan_k:1997b,mulligan_k:1997c,mulligan_k:1997d,mulligan_k:1997e,mulligan_r-etal:1997,mulligan_k:1998,mulligan_k:1998a,mulligan_k:1999,mulligan_k:1999a,mulligan_k:1999b,mulligan_k:1999c,mulligan_k:2000,mulligan_k:2000a,mulligan_k:2000b,mulligan_k:2000c,baertschi-mulligan:2001,baertschi-mulligan:2001a,cometti-mulligan:2001,mulligan_k:2001,mulligan_k:2001a,mulligan_k:2001b,mulligan_k:2001c,mulligan_k:2001d,mulligan_k:2002,mulligan_k:2002a,mulligan_k:2002b,engel_p-mulligan:2003,mulligan_k:2003,mulligan_k:2003a,mulligan_k:2003b,mulligan_k:2003c,mulligan_k:2003d,mulligan_k:2003e,hochberg-mulligan:2004,mulligan_k:2004,mulligan_k:2004a,mulligan_k:2004b,mulligan_k:2004c,smith_ba-mulligan:2005,mulligan_k-etal:2006,mulligan_k:2006,mulligan_k:2006a,mulligan_k:2006b,mulligan_k:2006c,mulligan_k:2006d,mulligan_k:2006e,mulligan_k:2007,mulligan_k:2007b,mulligan_k:2007c,mulligan_k:2008,mulligan_k:2008a,mulligan_k:2008b,mulligan_k-westerhoff:2009,mulligan_k-westerhoff:2009a,mulligan_k:2009,mulligan_k:2009a,mulligan_k:2009b,mulligan_k:2009c,mulligan_k:2009d,mulligan_k:2009e,mulligan_k:2009f,mulligan_k:2009g,baertschi-mulligan:2010,baertschi-mulligan:2010a,mulligan_k:2010,mulligan_k:2010a,mulligan_k:2010b,mulligan_k-etal:2011,mulligan_k:2011,mulligan_k:2011a,mulligan_k:2011b,mulligan_k-scherer:2012,mulligan_k-scherer:2012a,mulligan_k:2012,gerrans-mulligan:2013,mulligan_k-etal:2013,mulligan_k-etal:2013a,mulligan_k:2013a,mulligan_k:2013c,mulligan_k:2013e,mulligan_k:2013f,mulligan_k:2013g,mulligan_k:2014,mulligan_k:2014a,mulligan_k:2015,mulligan_k:2015a,mulligan_k:2015c,mulligan_k:2015d,mulligan_k:2015e,mulligan_k:2016,mulligan_k:2016a,mulligan_k:2016b,mulligan_k:2016c,cesalli-mulligan:2017,mulligan_k:2017,mulligan_k:2017a,mulligan_k:2017b,mulligan_k:2017c,mulligan_k:2017d,mulligan_k:2017e,mulligan_k:2018,mulligan_k:2019,mulligan_k:2020,massin-mulligan:2021,mulligan_k:2021,mulligan_k:2022,mulligan_k:2013d,mulligan_k-woodruff:unpub,mulligan_k:unpub,mulligan_k:unpub-a"

bib_deps_s = "amrein:2009,apel_ko-etal:2000,bachmaier_h:1990,besoli-guidetti:2000,bottani-davies:2006,burri_a:1997,calcaterra:2006,centi-gigliotti:2004,cohen_al-stern:2017,coliva-etal:2018,dewalque-etal:2021,doering_s:2009,dupuy_l-etal:2016,engel_p:2000,erismann_ch-schniewind:2008,eschbach:1988,fabian_r:1985,fischer_kr-stadler:1997,fisette_d-rialle:1996,fisette_d:1999,fossheim-etal:2003,frank_m-weidtmann:2010,frechette-taieb:2017,frechette:2015a,gargani:1993,garrett_bj-menzies:1993,goldie_p:2010,hales_sd:2001,hermeren-etal:2013,hintikka_j-etal:2003,hoefer_ul-valent:2017,husserl_e:1984,imaguire-schneider:2006,jacquette:2004,kriegel_u:2017,kuenne_w:2003,landweer-renz:2008,leibnizgesellschaft:1983,lepoidevin-etal:2009,lowe_ej-rami:2009,merker_b:2009,monnoyer:2007,moore_aw:2012,nef-etal:2017,nyiri_jc:1986,ogien_r-paperman:1995,ouelbani:2000,ouelbani:2002,padillagalvez-gaffal:2017,persson_i-etal:2015,philie:2015,plourde_j:2015,primiero-rahman:2009,puntel:1987,pynsent:1989,raven_mj:2020,roski_s-schnieder:2022,roth_ml-boeschenstein:1995,rueff_m-zanetta:2015,saellstroem:1983,salice-schmid:2016,schoenrich:2009,seron:2015a,siebel-textor:2004,smelser-baltes:2001,smith_ba-woodruffsmith:1995,smith_ba:1981a,smith_ba:1982,smith_ba:1988,smith_ba:2003,spohn-etal:1991,stoenescu-tanasescu:2005,svennerlind-etal:2013,szatkowski:2019,textor:2006,textor:2013,wittgensteinsymposium:1980,wittgensteinsymposium:1990a,zaibert:2016"

bib_keys = [s.strip() for s in bib_keys_s.split(',')]
bib_deps = [s.strip() for s in bib_deps_s.split(',')]

# %%
divs[0].get('id')

# %%
[get_id(div) for div in divs]
# Out:
# ['',
#  'c1-refs',
#  'ref-c1-baertschi-mulligan:2001',
#  'ref-c1-baertschi-mulligan:2001a',
#  'ref-c1-baertschi-mulligan:2010',
#  'ref-c1-baertschi-mulligan:2010a',
#  'ref-c1-cesalli-mulligan:2017',
#  'ref-c1-cometti-mulligan:2001',
#  'ref-c1-engel_p-mulligan:2003',
#  'ref-c1-frechette:2015a',
#  'ref-c1-garrett_bj-mulligan:1993',
#  'ref-c1-gerrans-mulligan:2013',
#  'ref-c1-hochberg-mulligan:2004',
#  'ref-c1-husserl_e:1984',
#  'ref-c1-kuenne_w:2003',
#  'ref-c1-leyvraz-mulligan:1993',
#  'ref-c1-massin-mulligan:2021',
#  'ref-c1-moore_aw:2012',
#  'ref-c1-mulligan_k:1980',
#  'ref-c1-mulligan_k:1981',
#  'ref-c1-mulligan_k:1983',
#  'ref-c1-mulligan_k:1983a',
#  'ref-c1-mulligan_k:1983b',
#  'ref-c1-mulligan_k:1985',
#  'ref-c1-mulligan_k:1986',
#  'ref-c1-mulligan_k:1987',
#  'ref-c1-mulligan_k:1987a',
#  'ref-c1-mulligan_k:1988',
#  'ref-c1-mulligan_k:1988a',
#  'ref-c1-mulligan_k:1988b',
#  'ref-c1-mulligan_k:1988c',
#  'ref-c1-mulligan_k:1989',
#  'ref-c1-mulligan_k:1990',
#  'ref-c1-mulligan_k:1990a',
#  'ref-c1-mulligan_k:1990b',
#  'ref-c1-mulligan_k:1990c',
#  'ref-c1-mulligan_k:1990d',
#  'ref-c1-mulligan_k:1990e',
#  'ref-c1-mulligan_k:1991',
#  'ref-c1-mulligan_k:1991a',
#  'ref-c1-mulligan_k:1991b',
#  'ref-c1-mulligan_k:1992',
#  'ref-c1-mulligan_k:1993',
#  'ref-c1-mulligan_k:1993a',
#  'ref-c1-mulligan_k:1993b',
#  'ref-c1-mulligan_k:1993c',
#  'ref-c1-mulligan_k:1995',
#  'ref-c1-mulligan_k:1995a',
#  'ref-c1-mulligan_k:1995b',
#  'ref-c1-mulligan_k:1996',
#  'ref-c1-mulligan_k:1997',
#  'ref-c1-mulligan_k:1997a',
#  'ref-c1-mulligan_k:1997b',
#  'ref-c1-mulligan_k:1997c',
#  'ref-c1-mulligan_k:1997d',
#  'ref-c1-mulligan_k:1997e',
#  'ref-c1-mulligan_k:1998',
#  'ref-c1-mulligan_k:1998a',
#  'ref-c1-mulligan_k:1999',
#  'ref-c1-mulligan_k:1999a',
#  'ref-c1-mulligan_k:1999b',
#  'ref-c1-mulligan_k:1999c',
#  'ref-c1-mulligan_k:2000',
#  'ref-c1-mulligan_k:2000a',
#  'ref-c1-mulligan_k:2000b',
#  'ref-c1-mulligan_k:2000c',
#  'ref-c1-mulligan_k:2001',
#  'ref-c1-mulligan_k:2001a',
#  'ref-c1-mulligan_k:2001b',
#  'ref-c1-mulligan_k:2001c',
#  'ref-c1-mulligan_k:2001d',
#  'ref-c1-mulligan_k:2002',
#  'ref-c1-mulligan_k:2002a',
#  'ref-c1-mulligan_k:2002b',
#  'ref-c1-mulligan_k:2003',
#  'ref-c1-mulligan_k:2003a',
#  'ref-c1-mulligan_k:2003b',
#  'ref-c1-mulligan_k:2003c',
#  'ref-c1-mulligan_k:2003d',
#  'ref-c1-mulligan_k:2003e',
#  'ref-c1-mulligan_k:2004',
#  'ref-c1-mulligan_k:2004a',
#  'ref-c1-mulligan_k:2004b',
#  'ref-c1-mulligan_k:2004c',
#  'ref-c1-mulligan_k:2006',
#  'ref-c1-mulligan_k:2006a',
#  'ref-c1-mulligan_k:2006b',
#  'ref-c1-mulligan_k:2006c',
#  'ref-c1-mulligan_k:2006d',
#  'ref-c1-mulligan_k:2006e',
#  'ref-c1-mulligan_k:2007',
#  'ref-c1-mulligan_k:2007b',
#  'ref-c1-mulligan_k:2007c',
#  'ref-c1-mulligan_k:2008',
#  'ref-c1-mulligan_k:2008a',
#  'ref-c1-mulligan_k:2008b',
#  'ref-c1-mulligan_k:2009',
#  'ref-c1-mulligan_k:2009a',
#  'ref-c1-mulligan_k:2009b',
#  'ref-c1-mulligan_k:2009c',
#  'ref-c1-mulligan_k:2009d',
#  'ref-c1-mulligan_k:2009e',
#  'ref-c1-mulligan_k:2009f',
#  'ref-c1-mulligan_k:2009g',
#  'ref-c1-mulligan_k:2010',
#  'ref-c1-mulligan_k:2010a',
#  'ref-c1-mulligan_k:2010b',
#  'ref-c1-mulligan_k:2011',
#  'ref-c1-mulligan_k:2011a',
#  'ref-c1-mulligan_k:2011b',
#  'ref-c1-mulligan_k:2012',
#  'ref-c1-mulligan_k:2013a',
#  'ref-c1-mulligan_k:2013c',
#  'ref-c1-mulligan_k:2013e',
#  'ref-c1-mulligan_k:2013f',
#  'ref-c1-mulligan_k:2013g',
#  'ref-c1-mulligan_k:2013d',
#  'ref-c1-mulligan_k:2014',
#  'ref-c1-mulligan_k:2014a',
#  'ref-c1-mulligan_k:2015',
#  'ref-c1-mulligan_k:2015a',
#  'ref-c1-mulligan_k:2015c',
#  'ref-c1-mulligan_k:2015d',
#  'ref-c1-mulligan_k:2015e',
#  'ref-c1-mulligan_k:2016',
#  'ref-c1-mulligan_k:2016a',
#  'ref-c1-mulligan_k:2016b',
#  'ref-c1-mulligan_k:2016c',
#  'ref-c1-mulligan_k:2017',
#  'ref-c1-mulligan_k:2017a',
#  'ref-c1-mulligan_k:2017b',
#  'ref-c1-mulligan_k:2017c',
#  'ref-c1-mulligan_k:2017d',
#  'ref-c1-mulligan_k:2017e',
#  'ref-c1-mulligan_k:2018',
#  'ref-c1-mulligan_k:2019',
#  'ref-c1-mulligan_k:2020',
#  'ref-c1-mulligan_k:2021',
#  'ref-c1-mulligan_k:2022',
#  'ref-c1-mulligan_k:unpub',
#  'ref-c1-mulligan_k:unpub-a',
#  'ref-c1-mulligan_k-etal:2013',
#  'ref-c1-mulligan_k-etal:2013a',
#  'ref-c1-mulligan_k-roth:1993',
#  'ref-c1-mulligan_k-rug:1985',
#  'ref-c1-mulligan_k-scherer:2012',
#  'ref-c1-mulligan_k-scherer:2012a',
#  'ref-c1-mulligan_k-schuhmann:1990',
#  'ref-c1-mulligan_k-etal:1984',
#  'ref-c1-mulligan_k-etal:1987',
#  'ref-c1-mulligan_k-etal:2006',
#  'ref-c1-mulligan_k-etal:2011',
#  'ref-c1-mulligan_k-smith:1983',
#  'ref-c1-mulligan_k-smith:1984',
#  'ref-c1-mulligan_k-smith:1985',
#  'ref-c1-mulligan_k-smith:1986',
#  'ref-c1-mulligan_k-smith:1986a',
#  'ref-c1-mulligan_k-smith:1986b',
#  'ref-c1-mulligan_k-westerhoff:2009',
#  'ref-c1-mulligan_k-westerhoff:2009a',
#  'ref-c1-mulligan_k-woodruff:unpub',
#  'ref-c1-mulligan_r-etal:1997',
#  'ref-c1-philie:2015',
#  'ref-c1-plourde_j:2015',
#  'ref-c1-seron:2015a',
#  'ref-c1-smith_ba-mulligan:1982',
#  'ref-c1-smith_ba-mulligan:1983',
#  'ref-c1-smith_ba-mulligan:1985',
#  'ref-c1-smith_ba-mulligan:1988',
#  'ref-c1-smith_ba-mulligan:2005']

# %%
from typing import List, TypeVar

T = TypeVar('T')

def flat(nested_list: List[ T | List[T]]) -> List[T]:
    return [item for sublist in nested_list for item in (flat(sublist) if isinstance(sublist, list) else [sublist])]

# %%
sub = [
    [
    div for div in divs if bib_key in get_id(div)
]
    for bib_key in bib_keys]

# %%
sub_flat = [item for sublist in sub for item in sublist]

# %%
print("\n".join([div.__str__() for div in sub_flat]))
# Out:
# <div class="csl-entry" id="ref-c1-mulligan_k:1980" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin. 1980. <span>“<span class="nocase">Structure and Rules in Wittgenstein and
# Husserl</span>.”</span> in <em><span class="nocase">Proceedings of the
# 4th International Wittgenstein Symposium: Language, Logic, and
# Philosophy</span></em>, edited by Rudolf <span class="smallcaps">Haller</span> and Wolfgang <span class="smallcaps">Grassl</span>, pp. 461–464. <span class="nocase">Schriftenreihe der <span>Ö</span>sterreichischen Ludwig
# Wittgenstein Gesellschaft</span> n. 4. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1981" role="listitem">
# —. 1981. <span>“<span class="nocase">Philosophy, Animality and Justice:
# Kleist, Kafka, Weininger and Wittgenstein</span>.”</span> in
# <em>Proceedings of the Aristotelian Society, Supplementary Volume</em>,
# volume 55, pp. 293–311.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1982" role="listitem">
# <span class="smallcaps">Smith</span>, Barry and <span class="smallcaps">Mulligan</span>, Kevin. 1982. <span>“<span class="nocase">Pieces of a Theory</span>.”</span> in <em><span class="nocase">Parts and Moments – Studies in Logic and Formal
# Ontology</span></em>, edited by Barry <span class="smallcaps">Smith</span>, pp. 15–109. <span class="nocase">Analytica: Investigations in Logic, Ontology, and the
# Philosophy of Language</span>. M<span>ü</span>nchen: Philosophia Verlag,
# doi:<a href="https://doi.org/10.2307/j.ctv2x8v896">10.2307/j.ctv2x8v896</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1983" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Smith</span>, Barry. 1983. <span>“<span class="nocase">Framework for Formal Ontology</span>.”</span>
# <em>Topoi</em> 2: 73–86.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983" role="listitem">
# —. 1983a. <span>“<span class="nocase">Constituency and Dependence in
# Language</span>.”</span> in <em><span class="nocase">Parts &amp;
# Wholes. An Inventory of Present Thinking about Parts and
# Wholes</span></em>, volume I, edited by Pehr <span class="smallcaps">Sällström</span>, pp. 75–89. Stockholm:
# Forsknings<span>å</span>dsn<span>ä</span>men.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983a" role="listitem">
# —. 1983b. <span>“<span class="nocase">Colours and
# Complexity</span>.”</span> in <em><span class="nocase">Parts &amp;
# Wholes. An Inventory of Present Thinking about Parts and
# Wholes</span></em>, volume I, edited by Pehr <span class="smallcaps">Sällström</span>, pp. 43–50. Stockholm:
# Forsknings<span>å</span>dsn<span>ä</span>men.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983b" role="listitem">
# —. 1983c. <span>“<span>Spinoza on Necessary Existential
# Determination</span>.”</span> in <em><span>Leibniz. Werk und
# Wirkung. IV. Internationaler
# Leibniz-Kongress. Vortr<span>ä</span>ge. Hannover, 14. bis 19. November
# 1983</span></em>, edited by <span class="smallcaps">G.W.-Leibniz-Gesellschaft</span>, pp. 532–539.
# Hannover: Leibniz Gesellschaft.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983a" role="listitem">
# —. 1983b. <span>“<span class="nocase">Colours and
# Complexity</span>.”</span> in <em><span class="nocase">Parts &amp;
# Wholes. An Inventory of Present Thinking about Parts and
# Wholes</span></em>, volume I, edited by Pehr <span class="smallcaps">Sällström</span>, pp. 43–50. Stockholm:
# Forsknings<span>å</span>dsn<span>ä</span>men.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1983b" role="listitem">
# —. 1983c. <span>“<span>Spinoza on Necessary Existential
# Determination</span>.”</span> in <em><span>Leibniz. Werk und
# Wirkung. IV. Internationaler
# Leibniz-Kongress. Vortr<span>ä</span>ge. Hannover, 14. bis 19. November
# 1983</span></em>, edited by <span class="smallcaps">G.W.-Leibniz-Gesellschaft</span>, pp. 532–539.
# Hannover: Leibniz Gesellschaft.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1983" role="listitem">
# —. 1983. <span>“<span class="nocase">Framework for Formal
# Ontology</span>.”</span> <em>Topoi</em> 2: 73–85.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:1984" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin, <span class="smallcaps">Simons</span>, Peter M. and <span class="smallcaps">Smith</span>, Barry. 1984.
# <span>“<span>Truth-Makers</span>.”</span> <em>Philosophy and
# Phenomenological Research</em> 44(3): 287–321.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1984" role="listitem">
# —. 1984. <span>“<span class="nocase">Traditional vs. Analytic
# Philosophy</span>.”</span> <em>Grazer Philosophische Studien</em> 21:
# 193–202.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-rug:1985" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Rug</span>, Reinhild. 1985. <span>“<span>Trieb und
# Theorie: Bemerkungen zu Ehrenfels und Freud</span>.”</span> in
# <em><span>Leben und Werk von Christian von Ehrenfels</span></em>, edited
# by Reinhard <span class="smallcaps">Fabian</span>, pp. 214–246.
# Amsterdam: Rodopi.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1985" role="listitem">
# —. 1985. <span>“<span class="nocase">Franz Brentano on the Ontology of
# Mind</span>.”</span> <em>Philosophy and Phenomenological Research</em>
# 45(4): 627–644.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1985" role="listitem">
# —. 1985. <span>“<span class="nocase"> <span>‘Wie die Sachen sich
# zueinander verhalten’</span>: Inside and Outside the
# Tractatus</span>.”</span> <em>Teoria</em> 5(2): 145–174.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1985" role="listitem">
# —. 1985. <span>“<span>Mach und Ehrenfels: <span>Ü</span>ber
# Gestaltqualit<span>ä</span>ten und das Problem der
# Abh<span>ä</span>ngigkeit</span>.”</span> in <em><span>Leben und Werk
# von Christian von Ehrenfels</span></em>, edited by Reinhard <span class="smallcaps">Fabian</span>, pp. 85–111. Amsterdam: Rodopi.
# <span>Expanded English version: <span class="citation" data-cites="smith_ba-mulligan:1988">Smith and Mulligan (<a href="#ref-c1-smith_ba-mulligan:1988" role="doc-biblioref">1988</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986" role="listitem">
# —. 1986a. <span>“<span class="nocase">A Relational Theory of the
# Act</span>.”</span> <em>Topoi</em> 5(2): 115–130.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986a" role="listitem">
# —. 1986b. <span>“<span class="nocase">A Husserlian Theory of
# Indexicality</span>.”</span> <em>Grazer Philosophische Studien</em> 28:
# 133–163. <span> <span>“Philosophische Aufs<span>ä</span>tze zu Ehren von
# Roderick M. Chisholm,”</span> ed. by Marian David and Leopold
# Stubenberg</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986b" role="listitem">
# —. 1986c. <span>“<span class="nocase">Husserl’s <em>Logical
# Investigations</em> [Review of <span class="citation" data-cites="husserl_e:1984">Husserl (<a href="#ref-c1-husserl_e:1984" role="doc-biblioref">1984</a>)</span>]</span>.”</span> <em>Grazer
# Philosophische Studien</em> 27: 199–207.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986a" role="listitem">
# —. 1986b. <span>“<span class="nocase">A Husserlian Theory of
# Indexicality</span>.”</span> <em>Grazer Philosophische Studien</em> 28:
# 133–163. <span> <span>“Philosophische Aufs<span>ä</span>tze zu Ehren von
# Roderick M. Chisholm,”</span> ed. by Marian David and Leopold
# Stubenberg</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-smith:1986b" role="listitem">
# —. 1986c. <span>“<span class="nocase">Husserl’s <em>Logical
# Investigations</em> [Review of <span class="citation" data-cites="husserl_e:1984">Husserl (<a href="#ref-c1-husserl_e:1984" role="doc-biblioref">1984</a>)</span>]</span>.”</span> <em>Grazer
# Philosophische Studien</em> 27: 199–207.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1986" role="listitem">
# —. 1986. <span>“<span class="nocase">Exactness, Description and
# Variation – How Austrian Analytic Philosophy was Done</span>.”</span> in
# <em><span class="nocase">From Bolzano to Wittgenstein: The Tradition of
# Austrian Philosophy</span></em>, edited by János Kristóf <span class="smallcaps">Nyı́ri</span>, pp. 86–97. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-etal:1987" role="listitem">
# —. 1987. <span>“<span>Wahrmacher</span>.”</span> in <em><span>Der
# Wahrheitsbegriff: neue Erkl<span>ä</span>rungsversuche</span></em>,
# edited by Lorenz Bruno <span class="smallcaps">Puntel</span>, pp.
# 210–255. <span>Wege der Forschung</span> n. 636. Darmstadt:
# Wissenschaftliche Buchgesellschaft. <span>Translation of <span class="citation" data-cites="mulligan_k-etal:1984">Mulligan, K., Simons
# and Smith (<a href="#ref-c1-mulligan_k-etal:1984" role="doc-biblioref">1984</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1987" role="listitem">
# —, ed. 1987a. <em><span class="nocase">Speech Act and Sachverhalt:
# Reinach and the Foundations of Realist Phenomenology</span></em>. Den
# Haag: Martinus Nijhoff Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1987a" role="listitem">
# —. 1987b. <span>“<span class="nocase">Promisings and other Social Acts:
# Their Constituents and Structure</span>.”</span> in <em><span class="nocase">Speech Act and Sachverhalt: Reinach and the Foundations
# of Realist Phenomenology</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 29–90. Den Haag: Martinus Nijhoff
# Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1987a" role="listitem">
# —. 1987b. <span>“<span class="nocase">Promisings and other Social Acts:
# Their Constituents and Structure</span>.”</span> in <em><span class="nocase">Speech Act and Sachverhalt: Reinach and the Foundations
# of Realist Phenomenology</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 29–90. Den Haag: Martinus Nijhoff
# Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988" role="listitem">
# —. 1988a. <span>“<span class="nocase">Judgings: Their Parts and
# Counterparts</span>.”</span> <em>Topoi</em> 2(suppl.): 117–148.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988a" role="listitem">
# —. 1988b. <span>“<span class="nocase">On the Notion of Structure: B<span class="nocase">ü</span>hler’s Linguistic and Psychological
# Examples</span>.”</span> in, edited by Achim <span class="smallcaps">Eschbach</span>, pp. 203–226. <span>Viennese Heritage
# / Wiener Erbe</span> n. 2. Amsterdam: John Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988b" role="listitem">
# —. 1988c. <span>“<span class="nocase">Seeing as and Assimilative
# Perception</span>.”</span> <em>Brentano Studien</em> 1: 129–152.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988c" role="listitem">
# —. 1988d. <span>“<span>La m<span>é</span>taphysique</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988a" role="listitem">
# —. 1988b. <span>“<span class="nocase">On the Notion of Structure: B<span class="nocase">ü</span>hler’s Linguistic and Psychological
# Examples</span>.”</span> in, edited by Achim <span class="smallcaps">Eschbach</span>, pp. 203–226. <span>Viennese Heritage
# / Wiener Erbe</span> n. 2. Amsterdam: John Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988b" role="listitem">
# —. 1988c. <span>“<span class="nocase">Seeing as and Assimilative
# Perception</span>.”</span> <em>Brentano Studien</em> 1: 129–152.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1988c" role="listitem">
# —. 1988d. <span>“<span>La m<span>é</span>taphysique</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-smith_ba-mulligan:1988" role="listitem">
# —. 1988. <span>“<span class="nocase">Mach and Ehrenfels: The Foundations
# of Gestalt Theory</span>.”</span> in <em><span class="nocase">Foundations of Gestalt Theory</span></em>, edited by
# Barry <span class="smallcaps">Smith</span>, pp. 124–157.
# <span>Philosophia Resources Library</span>. M<span>ü</span>nchen:
# Philosophia Verlag. <span>Expanded English version of <span class="citation" data-cites="smith_ba-mulligan:1985">Smith and Mulligan
# (<a href="#ref-c1-smith_ba-mulligan:1985" role="doc-biblioref">1985</a>)</span></span>, doi:<a href="https://doi.org/10.2307/j.ctv2x8v91j">10.2307/j.ctv2x8v91j</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1989" role="listitem">
# —. 1989. <span>“<span class="nocase">The Expression of Exactness: Ernst
# Mach, the Brentanists and the Ideal of Clarity</span>.”</span> in
# <em><span class="nocase">Decadence and Innovation. Austro-Hungarian Life
# and Art at the Turn of the Century</span></em>, edited by Robert <span class="smallcaps">Pynsent</span>, pp. 33–42. London: Weidenfeld;
# Nicolson.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-schuhmann:1990" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Schuhmann</span>, Karl. 1990. <span>“<span class="nocase">Two Letters from Marty to Husserl</span>.”</span> in
# <em><span class="nocase">Mind, Meaning and Metaphysics: The Philosophy
# and Theory of Language of Anton Marty</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 225–236. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990" role="listitem">
# —, ed. 1990a. <em><span class="nocase">Mind, Meaning and Metaphysics:
# The Philosophy and Theory of Language of Anton Marty</span></em>. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990a" role="listitem">
# —. 1990b. <span>“<span class="nocase">Criteria and
# Indication</span>.”</span> in <em><span class="nocase">Proceedings of
# the 14th International Wittgenstein Symposium: Wittgenstein – Towards a
# Re-Evaluation. Volume II</span></em>, edited by Rudolf <span class="smallcaps">Haller</span> and Johannes L. <span class="smallcaps">Brandl</span>, pp. 94–105. <span class="nocase">Schriftenreihe der <span>Ö</span>sterreichischen Ludwig
# Wittgenstein Gesellschaft</span> n. 19/2. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990b" role="listitem">
# —. 1990c. <span>“<span>Genauigkeit und Geschw<span>ä</span>tz – Glossen
# zu einem paradigmatischen Gegensatz in der Philosophie</span>.”</span>
# in <em><span>Wien – Paradigmen der Moderne</span></em>, edited by H.
# <span class="smallcaps">Bachmaier</span>, pp. 209–236. Amsterdam: John
# Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990c" role="listitem">
# —. 1990d. <span>“<span class="nocase">Marty’s Philosophical
# Grammar</span>.”</span> in <em><span class="nocase">Mind, Meaning and
# Metaphysics: The Philosophy and Theory of Language of Anton
# Marty</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 11–28. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990d" role="listitem">
# —. 1990e. <span>“<span class="nocase">Husserl on States of Affairs in
# the <em>Logical Investigations</em></span>.”</span>
# <em>Epistemologia. An International Review for the Philosophy of
# Science</em> 12: 207–234.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990e" role="listitem">
# —. 1990f. <span>“<span>Las situaciones objetivas en las
# <em>Investigaciones Logicas</em> de Edmundo Husserl</span>.”</span>
# <em>Revista de filosofia</em> 3(3): 23–49.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990a" role="listitem">
# —. 1990b. <span>“<span class="nocase">Criteria and
# Indication</span>.”</span> in <em><span class="nocase">Proceedings of
# the 14th International Wittgenstein Symposium: Wittgenstein – Towards a
# Re-Evaluation. Volume II</span></em>, edited by Rudolf <span class="smallcaps">Haller</span> and Johannes L. <span class="smallcaps">Brandl</span>, pp. 94–105. <span class="nocase">Schriftenreihe der <span>Ö</span>sterreichischen Ludwig
# Wittgenstein Gesellschaft</span> n. 19/2. Wien:
# H<span>ö</span>lder-Pichler-Tempsky.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990b" role="listitem">
# —. 1990c. <span>“<span>Genauigkeit und Geschw<span>ä</span>tz – Glossen
# zu einem paradigmatischen Gegensatz in der Philosophie</span>.”</span>
# in <em><span>Wien – Paradigmen der Moderne</span></em>, edited by H.
# <span class="smallcaps">Bachmaier</span>, pp. 209–236. Amsterdam: John
# Benjamins Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990c" role="listitem">
# —. 1990d. <span>“<span class="nocase">Marty’s Philosophical
# Grammar</span>.”</span> in <em><span class="nocase">Mind, Meaning and
# Metaphysics: The Philosophy and Theory of Language of Anton
# Marty</span></em>, edited by Kevin <span class="smallcaps">Mulligan</span>, pp. 11–28. <span class="nocase">Primary Sources in Phenomenology</span> n. 3. Dordrecht:
# Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990d" role="listitem">
# —. 1990e. <span>“<span class="nocase">Husserl on States of Affairs in
# the <em>Logical Investigations</em></span>.”</span>
# <em>Epistemologia. An International Review for the Philosophy of
# Science</em> 12: 207–234.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1990e" role="listitem">
# —. 1990f. <span>“<span>Las situaciones objetivas en las
# <em>Investigaciones Logicas</em> de Edmundo Husserl</span>.”</span>
# <em>Revista de filosofia</em> 3(3): 23–49.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991" role="listitem">
# —. 1991a. <span>“<span class="nocase">Introduction: On the History of
# Continental Philosophy</span>.”</span> <em>Topoi</em> 10(2): 115–120.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991a" role="listitem">
# —. 1991b. <span>“<span class="nocase">Colours, Corners and Complexity:
# Meinong and Wittgenstein on Some Internal Relations</span>.”</span> in
# <em><span class="nocase">Existence and Explanation. Essays presented in
# Honor of Karel Lambert</span></em>, edited by Wolfgang <span class="smallcaps">Spohn</span>, Bas C. van <span class="smallcaps">Fraassen</span>, and Brian <span class="smallcaps">Skyrms</span>, pp. 77–101. <span class="nocase">The
# University of Western Ontario Series in Philosophy of Science</span>
# n. 49. Dordrecht: Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991b" role="listitem">
# —. 1991c. <span>“<span class="nocase">How Not to Read: Derrida on
# Husserl</span>.”</span> <em>Topoi</em> 10(2): 199–208.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991a" role="listitem">
# —. 1991b. <span>“<span class="nocase">Colours, Corners and Complexity:
# Meinong and Wittgenstein on Some Internal Relations</span>.”</span> in
# <em><span class="nocase">Existence and Explanation. Essays presented in
# Honor of Karel Lambert</span></em>, edited by Wolfgang <span class="smallcaps">Spohn</span>, Bas C. van <span class="smallcaps">Fraassen</span>, and Brian <span class="smallcaps">Skyrms</span>, pp. 77–101. <span class="nocase">The
# University of Western Ontario Series in Philosophy of Science</span>
# n. 49. Dordrecht: Kluwer Academic Publishers.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1991b" role="listitem">
# —. 1991c. <span>“<span class="nocase">How Not to Read: Derrida on
# Husserl</span>.”</span> <em>Topoi</em> 10(2): 199–208.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1992" role="listitem">
# —, ed. 1992. <em><span class="nocase">Language, Truth and
# Ontology</span></em>. <span>Philosophical Studies Series</span> n. 51.
# Dordrecht: D. Reidel Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-garrett_bj-mulligan:1993" role="listitem">
# <span class="smallcaps">Garrett</span>, Brian John and <span class="smallcaps">Mulligan</span>, Kevin, eds. 1993. <em><span class="nocase">Themes from Wittgenstein</span></em>. <span class="nocase">Working Papers in Philosophy</span> n. 4. Canberra: RSSS
# Australasian National University.
# </div>
# <div class="csl-entry" id="ref-c1-leyvraz-mulligan:1993" role="listitem">
# <span class="smallcaps">Leyvraz</span>, Jean-Pierre and <span class="smallcaps">Mulligan</span>, Kevin, eds. 1993.
# <em><span>Wittgenstein analys<span>é</span></span></em>.
# N<span>î</span>mes: <span>É</span>ditions Jacqueline Chambon.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-roth:1993" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Roth</span>, Robert J., eds. 1993. <em><span>Regards
# sur Bentham et l’utilitarisme (Actes du colloque organis<span>é</span>
# <span>à</span> Gen<span>è</span>ve les 23 et 24 novembre
# 1990)</span></em>. <span>Recherches et Rencontres</span> n. 4.
# Gen<span>è</span>ve: Droz.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993" role="listitem">
# —. 1993a. <span>“<span>Internal Relations</span>.”</span> in
# <em><span>1992 ANU Metaphysics Conference</span></em>, edited by Brian
# John <span class="smallcaps">Garrett</span> and Peter <span class="smallcaps">Menzies</span>, pp. 1–22. <span class="nocase">Working
# Papers in Philosophy</span> n. 2. Canberra: RSSS Australasian National
# University.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993a" role="listitem">
# —. 1993b. <span>“<span>Proposizione, stato di cose ed altri concetti
# formali nel pensiero di Husserl e Wittgenstein</span>.”</span> in
# <em><span>L’Uomo, un segno – Wittgenstein contemporaneo</span></em>,
# edited by Aldo Giorgio <span class="smallcaps">Gargani</span>, pp.
# 41–65. Genova: Marietti.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993b" role="listitem">
# —. 1993c. <span>“<span>Post-Continental Philosophy: Nosological
# Notes</span>.”</span> <em>Stanford French Review</em> 17(2–3): 133–150.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993c" role="listitem">
# —. 1993d. <span>“<span class="nocase">Description’s Objects: Austrian
# Variations</span>.”</span> in <em><span class="nocase">Themes from
# Wittgenstein</span></em>, edited by Brian John <span class="smallcaps">Garrett</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 62–85. <span class="nocase">Working Papers in Philosophy</span> n. 4. Canberra: RSSS
# Australasian National University.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993a" role="listitem">
# —. 1993b. <span>“<span>Proposizione, stato di cose ed altri concetti
# formali nel pensiero di Husserl e Wittgenstein</span>.”</span> in
# <em><span>L’Uomo, un segno – Wittgenstein contemporaneo</span></em>,
# edited by Aldo Giorgio <span class="smallcaps">Gargani</span>, pp.
# 41–65. Genova: Marietti.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993b" role="listitem">
# —. 1993c. <span>“<span>Post-Continental Philosophy: Nosological
# Notes</span>.”</span> <em>Stanford French Review</em> 17(2–3): 133–150.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1993c" role="listitem">
# —. 1993d. <span>“<span class="nocase">Description’s Objects: Austrian
# Variations</span>.”</span> in <em><span class="nocase">Themes from
# Wittgenstein</span></em>, edited by Brian John <span class="smallcaps">Garrett</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 62–85. <span class="nocase">Working Papers in Philosophy</span> n. 4. Canberra: RSSS
# Australasian National University.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1995" role="listitem">
# —. 1995a. <span>“<span>Le spectre de l’affect inverti et l’espace des
# <span>é</span>motions</span>.”</span> in <em><span>La couleur des
# pens<span>é</span>es. Sentiments, <span>é</span>motions,
# intentions</span></em>, edited by Ruwen <span class="smallcaps">Ogien</span> and Patricia <span class="smallcaps">Paperman</span>, pp. 65–83. Paris:
# <span>É</span>ditions de l’<span>é</span>cole des hautes
# <span>é</span>tudes en sciences sociales. <span>Translated as <span class="citation" data-cites="mulligan_k:1997b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1997b" role="doc-biblioref">1997c</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1995a" role="listitem">
# —. 1995b. <span>“<span>Perception</span>.”</span> in <em><span class="nocase">The Cambridge Companion to Husserl</span></em>, edited by
# Barry <span class="smallcaps">Smith</span> and David <span class="smallcaps">Woodruff Smith</span>, pp. 168–238. <span class="nocase">Cambridge Companions to Philosophy</span>. Cambridge:
# Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1995b" role="listitem">
# —. 1995c. <span>“<span>Musils Analyse des
# Gef<span>ü</span>hls</span>.”</span> in <em><span>Hommage <span>à</span>
# Musil. Genfer Kolloquium zum 50. Todestag von Robert Musil</span></em>,
# edited by Marie-Louise <span class="smallcaps">Roth</span> and Bernhard
# <span class="smallcaps">Böschenstein</span>, pp. 87–110.
# <span>Musiliana</span> n. 1. Frankfurt a.M.: Peter Lang.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1995a" role="listitem">
# —. 1995b. <span>“<span>Perception</span>.”</span> in <em><span class="nocase">The Cambridge Companion to Husserl</span></em>, edited by
# Barry <span class="smallcaps">Smith</span> and David <span class="smallcaps">Woodruff Smith</span>, pp. 168–238. <span class="nocase">Cambridge Companions to Philosophy</span>. Cambridge:
# Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1995b" role="listitem">
# —. 1995c. <span>“<span>Musils Analyse des
# Gef<span>ü</span>hls</span>.”</span> in <em><span>Hommage <span>à</span>
# Musil. Genfer Kolloquium zum 50. Todestag von Robert Musil</span></em>,
# edited by Marie-Louise <span class="smallcaps">Roth</span> and Bernhard
# <span class="smallcaps">Böschenstein</span>, pp. 87–110.
# <span>Musiliana</span> n. 1. Frankfurt a.M.: Peter Lang.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1996" role="listitem">
# —. 1996. <span>“<span>Constancy, Content and Sense</span>.”</span> in
# <em><span>Penser l’esprit</span></em>, edited by Denis <span class="smallcaps">Fisette</span> and V. <span class="smallcaps">Rialle</span>, pp. 141–150. Grenoble: Presses
# Universitaires de Grenoble.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997" role="listitem">
# —. 1997a. <span>“<span class="nocase">The Essence of Language:
# Wittgenstein’s Builders and B<span class="nocase">ü</span>hler’s
# Bricks</span>.”</span> <em>Revue de M<span>é</span>taphysique et de
# Morale</em> 102(2): 193–216.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997a" role="listitem">
# —. 1997b. <span>“<span>How Perception Fixes Reference</span>.”</span> in
# <em><span>Sprache und Denken / Language and Thought</span></em>, pp.
# 122–138. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997b" role="listitem">
# —. 1997c. <span>“<span class="nocase">The Spectre of Inverted Emotions
# and the Space of Emotions</span>.”</span> <em>Acta Analytica</em>
# 12(18): 89–105. <span>Translation of <span class="citation" data-cites="mulligan_k:1995">Mulligan, K. (<a href="#ref-c1-mulligan_k:1995" role="doc-biblioref">1995a</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997c" role="listitem">
# —. 1997d. <span>“<span>Konstanz und Kriterien: Brunswiks
# Beitrag</span>.”</span> in <em><span> <span>“Wahrnehmung und
# Gegenstandswelt.”</span> Zum Lebenswerk von Egon Brunswik
# (1903–1955)</span></em>, edited by Kurt Rudolf <span class="smallcaps">Fischer</span> and Friedrich <span class="smallcaps">Stadler</span>, pp. 137–150.
# <span>Ver<span>ö</span>ffentlichungen des Instituts Wiener Kreis</span>
# n. 4. Wien: Institute Vienna Circle. Society for the Advancement of the
# Scientific World Conception.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997d" role="listitem">
# —. 1997e. <span>“<span>Das Wesen der Sprache: Wittgensteins Maurer und
# B<span>ü</span>hlers Bausteine</span>.”</span> <em>Brentano Studien</em>
# 7: 267–290.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997e" role="listitem">
# —. 1997f. <span>“<span>Lo stato di cose nelle <em>Ricerche Logiche</em>
# di Husserl</span>.”</span> <em>Discipline filosofiche</em> 2: 127–158.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997a" role="listitem">
# —. 1997b. <span>“<span>How Perception Fixes Reference</span>.”</span> in
# <em><span>Sprache und Denken / Language and Thought</span></em>, pp.
# 122–138. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997b" role="listitem">
# —. 1997c. <span>“<span class="nocase">The Spectre of Inverted Emotions
# and the Space of Emotions</span>.”</span> <em>Acta Analytica</em>
# 12(18): 89–105. <span>Translation of <span class="citation" data-cites="mulligan_k:1995">Mulligan, K. (<a href="#ref-c1-mulligan_k:1995" role="doc-biblioref">1995a</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997c" role="listitem">
# —. 1997d. <span>“<span>Konstanz und Kriterien: Brunswiks
# Beitrag</span>.”</span> in <em><span> <span>“Wahrnehmung und
# Gegenstandswelt.”</span> Zum Lebenswerk von Egon Brunswik
# (1903–1955)</span></em>, edited by Kurt Rudolf <span class="smallcaps">Fischer</span> and Friedrich <span class="smallcaps">Stadler</span>, pp. 137–150.
# <span>Ver<span>ö</span>ffentlichungen des Instituts Wiener Kreis</span>
# n. 4. Wien: Institute Vienna Circle. Society for the Advancement of the
# Scientific World Conception.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997d" role="listitem">
# —. 1997e. <span>“<span>Das Wesen der Sprache: Wittgensteins Maurer und
# B<span>ü</span>hlers Bausteine</span>.”</span> <em>Brentano Studien</em>
# 7: 267–290.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1997e" role="listitem">
# —. 1997f. <span>“<span>Lo stato di cose nelle <em>Ricerche Logiche</em>
# di Husserl</span>.”</span> <em>Discipline filosofiche</em> 2: 127–158.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_r-etal:1997" role="listitem">
# <span class="smallcaps">Mulligan</span>, R., <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Juillerat</span>, Anne-Claude. 1997. <span>“<span>La
# m<span>é</span>moire affective: Le cas de la douleur</span>.”</span>
# <em>Cahiers psychiatriques</em> 23: 157–161.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1998" role="listitem">
# —. 1998a. <span>“<span class="nocase">Relations – Through Thick and
# Thin</span>.”</span> <em>Erkenntnis</em> 48: 325–353.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1998a" role="listitem">
# —. 1998b. <span>“<span class="nocase">From Appropriate Emotions to
# Values</span>.”</span> <em>The Monist</em> 81(1): 161–188.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1998a" role="listitem">
# —. 1998b. <span>“<span class="nocase">From Appropriate Emotions to
# Values</span>.”</span> <em>The Monist</em> 81(1): 161–188.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999" role="listitem">
# —. 1999a. <span>“<span class="nocase">Justification, Rule-Breaking and
# the Mind</span>.”</span> <em>Proceedings of the Aristotelian
# Society</em> 99: 123–139.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999a" role="listitem">
# —. 1999b. <span>“<span>Exactitude et bavardage. Glosses pour une
# opposition paradigmatique dans la philosophie
# autrichienne</span>.”</span> <em>Philosophiques</em> 26(2): 177–201.
# <span>Traduction fran<span>ç</span>aise de <span class="citation" data-cites="mulligan_k:1990b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990b" role="doc-biblioref">1990c</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999b" role="listitem">
# —. 1999c. <span>“<span>La Variet<span>à</span> e l’Unit<span>à</span>
# dell’Immaginazione</span>.”</span> <em>Rivista di Estetica</em> 11(2):
# 53–67.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999c" role="listitem">
# —. 1999d. <span>“<span class="nocase">Perception, Particulars and
# Predicates</span>.”</span> in <em><span class="nocase">Consciousness and
# Intentionality: Models and Modalities of Attribution</span></em>, edited
# by Denis <span class="smallcaps">Fisette</span>, pp. 163–194. <span class="nocase">The University of Western Ontario Series in Philosophy of
# Science</span> n. 62. Dordrecht: Kluwer Academic Publishers, doi:<a href="https://doi.org/10.1007/978-94-015-9193-5_8">10.1007/978-94-015-9193-5_8</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999a" role="listitem">
# —. 1999b. <span>“<span>Exactitude et bavardage. Glosses pour une
# opposition paradigmatique dans la philosophie
# autrichienne</span>.”</span> <em>Philosophiques</em> 26(2): 177–201.
# <span>Traduction fran<span>ç</span>aise de <span class="citation" data-cites="mulligan_k:1990b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1990b" role="doc-biblioref">1990c</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999b" role="listitem">
# —. 1999c. <span>“<span>La Variet<span>à</span> e l’Unit<span>à</span>
# dell’Immaginazione</span>.”</span> <em>Rivista di Estetica</em> 11(2):
# 53–67.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:1999c" role="listitem">
# —. 1999d. <span>“<span class="nocase">Perception, Particulars and
# Predicates</span>.”</span> in <em><span class="nocase">Consciousness and
# Intentionality: Models and Modalities of Attribution</span></em>, edited
# by Denis <span class="smallcaps">Fisette</span>, pp. 163–194. <span class="nocase">The University of Western Ontario Series in Philosophy of
# Science</span> n. 62. Dordrecht: Kluwer Academic Publishers, doi:<a href="https://doi.org/10.1007/978-94-015-9193-5_8">10.1007/978-94-015-9193-5_8</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000" role="listitem">
# —. 2000a. <span>“<span>M<span>é</span>taphysique et
# ontologie</span>.”</span> in <em><span>Pr<span>é</span>cis de
# philosophie analytique</span></em>, edited by Pascal <span class="smallcaps">Engel</span>, pp. 5–33. Paris: Presses Universitaires
# de France.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000a" role="listitem">
# —. 2000b. <span>“<span>C’<span>é</span>tait quoi la philosophie dite
# <span>‘continentale’</span>?</span>”</span> in <em><span>Un
# si<span>è</span>cle de philosophie 1900-2000</span></em>, edited by
# Karl-Otto <span class="smallcaps">Apel</span>, Jonathan <span class="smallcaps">Barnes</span>, Enrico <span class="smallcaps">Bellone</span>, Catherine <span class="smallcaps">Chevalley</span>, Gerald A. <span class="smallcaps">Cohen</span>, Jean <span class="smallcaps">Cournut</span>, Vincent <span class="smallcaps">Descombes</span>, et al., pp. 332–366. <span>Folio
# essais</span> n. 369. Paris: Gallimard. <span>Traduction de <span class="citation" data-cites="mulligan_k:1993b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993b" role="doc-biblioref">1993c</a>)</span>
# par Christian Fournier</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000b" role="listitem">
# —. 2000c. <span>“<span>Promesse ed altri atti sociali: costituenti e
# struttura</span>.”</span> in <em><span>Il Realismo Fenomenologico. Sulla
# filosofia dei circoli di Monaco e Gottinga</span></em>, edited by
# Stefano <span class="smallcaps">Besoli</span> and L. <span class="smallcaps">Guidetti</span>, pp. 309–384. Macerata: Quodlibet.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000c" role="listitem">
# —. 2000d. <span>“<span>La philosophie autrichienne – quelques variations
# constantes</span>.”</span> in <em><span>La philosophie
# autrichienne</span></em>, edited by Mélika <span class="smallcaps">Ouelbani</span>, pp. 9–26. Tunis:
# Universit<span>é</span> de Tunis.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000a" role="listitem">
# —. 2000b. <span>“<span>C’<span>é</span>tait quoi la philosophie dite
# <span>‘continentale’</span>?</span>”</span> in <em><span>Un
# si<span>è</span>cle de philosophie 1900-2000</span></em>, edited by
# Karl-Otto <span class="smallcaps">Apel</span>, Jonathan <span class="smallcaps">Barnes</span>, Enrico <span class="smallcaps">Bellone</span>, Catherine <span class="smallcaps">Chevalley</span>, Gerald A. <span class="smallcaps">Cohen</span>, Jean <span class="smallcaps">Cournut</span>, Vincent <span class="smallcaps">Descombes</span>, et al., pp. 332–366. <span>Folio
# essais</span> n. 369. Paris: Gallimard. <span>Traduction de <span class="citation" data-cites="mulligan_k:1993b">Mulligan, K. (<a href="#ref-c1-mulligan_k:1993b" role="doc-biblioref">1993c</a>)</span>
# par Christian Fournier</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000b" role="listitem">
# —. 2000c. <span>“<span>Promesse ed altri atti sociali: costituenti e
# struttura</span>.”</span> in <em><span>Il Realismo Fenomenologico. Sulla
# filosofia dei circoli di Monaco e Gottinga</span></em>, edited by
# Stefano <span class="smallcaps">Besoli</span> and L. <span class="smallcaps">Guidetti</span>, pp. 309–384. Macerata: Quodlibet.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2000c" role="listitem">
# —. 2000d. <span>“<span>La philosophie autrichienne – quelques variations
# constantes</span>.”</span> in <em><span>La philosophie
# autrichienne</span></em>, edited by Mélika <span class="smallcaps">Ouelbani</span>, pp. 9–26. Tunis:
# Universit<span>é</span> de Tunis.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2001" role="listitem">
# <span class="smallcaps">Baertschi</span>, Bernard and <span class="smallcaps">Mulligan</span>, Kevin, eds. 2001a. <em><span>Les
# nationalismes</span></em>. <span><span>É</span>thique et philosophie
# morale</span>. Paris: Presses Universitaires de France.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2001a" role="listitem">
# —. 2001b. <span>“<span>Introduction</span>.”</span> in <em><span>Les
# nationalismes</span></em>, edited by Bernard <span class="smallcaps">Baertschi</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 3–11. <span><span>É</span>thique
# et philosophie morale</span>. Paris: Presses Universitaires de France.
# </div>
# <div class="csl-entry" id="ref-c1-baertschi-mulligan:2001a" role="listitem">
# —. 2001b. <span>“<span>Introduction</span>.”</span> in <em><span>Les
# nationalismes</span></em>, edited by Bernard <span class="smallcaps">Baertschi</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 3–11. <span><span>É</span>thique
# et philosophie morale</span>. Paris: Presses Universitaires de France.
# </div>
# <div class="csl-entry" id="ref-c1-cometti-mulligan:2001" role="listitem">
# <span class="smallcaps">Cometti</span>, Jean-Pierre and <span class="smallcaps">Mulligan</span>, Kevin, eds. 2001. <em><span>La
# philosophie autrichienne de Bolzano <span>à</span> Musil. Histoire et
# actualit<span>é</span> (Actes du colloque de 1997 <span>à</span>
# Cerisy-la-Salle)</span></em>. <span>Probl<span>è</span>mes &amp;
# Controverses</span>. Paris: Librairie philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001" role="listitem">
# —. 2001a. <span>“<span class="nocase">A History of Early Analytic
# Metaphysics</span>.”</span> in <em><span>Analytic Philosophy: Classical
# Readings</span></em>, edited by Steven D. <span class="smallcaps">Hales</span>, pp. 83–92. Belmont, California:
# Wadsworth Publishing Co.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001a" role="listitem">
# —. 2001b. <span>“<span>De la philosophie autrichienne et de sa
# place</span>.”</span> in <em><span>La philosophie autrichienne de
# Bolzano <span>à</span> Musil. Histoire et actualit<span>é</span> (Actes
# du colloque de 1997 <span>à</span> Cerisy-la-Salle)</span></em>, edited
# by Jean-Pierre <span class="smallcaps">Cometti</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 7–27.
# <span>Probl<span>è</span>mes &amp; Controverses</span>. Paris: Librairie
# philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001b" role="listitem">
# —. 2001c. <span>“<span class="nocase">Logical Positivism and Logical
# Empiricism</span>.”</span> in <em><span class="nocase">The International
# Encyclopedia of the Social and Behavioral Sciences</span></em>, edited
# by Neil J. <span class="smallcaps">Smelser</span> and Paul B. <span class="smallcaps">Baltes</span>, pp. 9036–9038. Amsterdam: Elsevier
# Science Publishers B.V.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001c" role="listitem">
# —. 2001d. <span>“<span>Phenomenology: Philosophical
# Aspects</span>.”</span> in <em><span class="nocase">The International
# Encyclopedia of the Social and Behavioral Sciences</span></em>, edited
# by Neil J. <span class="smallcaps">Smelser</span> and Paul B. <span class="smallcaps">Baltes</span>, pp. 11363–11369. Amsterdam: Elsevier
# Science Publishers B.V.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001d" role="listitem">
# —. 2001e. <span>“<span>Actes i objectes. Una an<span>à</span>lisi de la
# fenomenologia realista</span>.”</span> <em>Anuari de la societat
# catalana de filosofia</em> 13: 241–262.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001a" role="listitem">
# —. 2001b. <span>“<span>De la philosophie autrichienne et de sa
# place</span>.”</span> in <em><span>La philosophie autrichienne de
# Bolzano <span>à</span> Musil. Histoire et actualit<span>é</span> (Actes
# du colloque de 1997 <span>à</span> Cerisy-la-Salle)</span></em>, edited
# by Jean-Pierre <span class="smallcaps">Cometti</span> and Kevin <span class="smallcaps">Mulligan</span>, pp. 7–27.
# <span>Probl<span>è</span>mes &amp; Controverses</span>. Paris: Librairie
# philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001b" role="listitem">
# —. 2001c. <span>“<span class="nocase">Logical Positivism and Logical
# Empiricism</span>.”</span> in <em><span class="nocase">The International
# Encyclopedia of the Social and Behavioral Sciences</span></em>, edited
# by Neil J. <span class="smallcaps">Smelser</span> and Paul B. <span class="smallcaps">Baltes</span>, pp. 9036–9038. Amsterdam: Elsevier
# Science Publishers B.V.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001c" role="listitem">
# —. 2001d. <span>“<span>Phenomenology: Philosophical
# Aspects</span>.”</span> in <em><span class="nocase">The International
# Encyclopedia of the Social and Behavioral Sciences</span></em>, edited
# by Neil J. <span class="smallcaps">Smelser</span> and Paul B. <span class="smallcaps">Baltes</span>, pp. 11363–11369. Amsterdam: Elsevier
# Science Publishers B.V.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2001d" role="listitem">
# —. 2001e. <span>“<span>Actes i objectes. Una an<span>à</span>lisi de la
# fenomenologia realista</span>.”</span> <em>Anuari de la societat
# catalana de filosofia</em> 13: 241–262.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2002" role="listitem">
# —. 2002a. <span>“<span>Getting Geist – Certainty, Rules and
# Us</span>.”</span> in <em><span>Cinquantenaire de Ludwig Wittgenstein:
# Actes du Colloque, Facult<span>é</span> des Sciences Humaines et
# Sociales, 13-15 novembre 2001</span></em>, edited by Mélika <span class="smallcaps">Ouelbani</span>, pp. 35–62. Tunis:
# Facult<span>é</span> des Sciences Humaines et Sociales.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2002a" role="listitem">
# —. 2002b. <span>“<span>Actes socials i objectes socials</span>.”</span>
# <em>Comprendre. Revista catalana de filosofia</em> 4(2): 193–204.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2002b" role="listitem">
# —. 2002c. <span>“<span>Metafisica e ontologia</span>.”</span> <em>Aut
# Aut</em> 310–311: 116–143.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2002a" role="listitem">
# —. 2002b. <span>“<span>Actes socials i objectes socials</span>.”</span>
# <em>Comprendre. Revista catalana de filosofia</em> 4(2): 193–204.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2002b" role="listitem">
# —. 2002c. <span>“<span>Metafisica e ontologia</span>.”</span> <em>Aut
# Aut</em> 310–311: 116–143.
# </div>
# <div class="csl-entry" id="ref-c1-engel_p-mulligan:2003" role="listitem">
# <span class="smallcaps">Engel</span>, Pascal and <span class="smallcaps">Mulligan</span>, Kevin. 2003. <span>“<span>Normes
# <span>é</span>thiques et normes cognitives</span>.”</span>
# <em>Cit<span>é</span>s</em> 15: 171–186.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003" role="listitem">
# —. 2003a. <span>“<span>Stati di cose, verit<span>à</span> e fattori di
# verit<span>à</span></span>.”</span> <em>Sistemi Intelligenti</em> 15(3):
# 539–556.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003a" role="listitem">
# —. 2003b. <span>“<span class="nocase">Searle, Derrida, and the Ends of
# Phenomenology</span>.”</span> in <em><span>John Searle</span></em>,
# edited by Barry <span class="smallcaps">Smith</span>, pp. 261–286. <span class="nocase">Contemporary Philosophy in Focus</span>. Cambridge:
# Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003b" role="listitem">
# —. 2003c. <span>“<span class="nocase">Seeing, Certainty and
# Apprehension</span>.”</span> in <em><span class="nocase">Non-Conceptual
# Aspects of Experience</span></em>, edited by Hallvard J. <span class="smallcaps">Fossheim</span>, Tarjej <span class="smallcaps">Mandt
# Larsen</span>, and John Rickard <span class="smallcaps">Sageng</span>,
# pp. 193–211. Oslo: Unipub forlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003c" role="listitem">
# —. 2003d. <span>“<span class="nocase">Dispositions, their Bases and
# Correlates – Meinong’s Analysis</span>.”</span> in <em><span class="nocase">Philosophy and Logic. In Search of the Polish
# Tradition. Essays in Honour of Jan Wole<span class="nocase">ń</span>ski
# on the Occasion of his 60th Birthday</span></em>, edited by Jaakko <span class="smallcaps">Hintikka</span>, Tadeusz <span class="smallcaps">Czarnecki</span>, Katarzyna <span class="smallcaps">Kijania-Placek</span>, Tomasz <span class="smallcaps">Placek</span>, and Artur <span class="smallcaps">Rojszczak</span>, pp. 193–212. <span>Synthese
# Library</span> n. 323. Dordrecht: Kluwer Academic Publishers, doi:<a href="https://doi.org/10.1007/978-94-017-0249-2">10.1007/978-94-017-0249-2</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003d" role="listitem">
# —. 2003e. <span>“<span>La filosofia analitica: che cosa <span>è</span>
# stata e che cosa ha da essere</span>.”</span> <em>Iride: Filosofia e
# Discussione Publica</em> 40: 631–634.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003e" role="listitem">
# —. 2003f. <span>“<span class="nocase">Forms of Life or Ways of
# Life?</span>”</span> <em>Rivista di Estetica</em> 24(3): 106–108.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003a" role="listitem">
# —. 2003b. <span>“<span class="nocase">Searle, Derrida, and the Ends of
# Phenomenology</span>.”</span> in <em><span>John Searle</span></em>,
# edited by Barry <span class="smallcaps">Smith</span>, pp. 261–286. <span class="nocase">Contemporary Philosophy in Focus</span>. Cambridge:
# Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003b" role="listitem">
# —. 2003c. <span>“<span class="nocase">Seeing, Certainty and
# Apprehension</span>.”</span> in <em><span class="nocase">Non-Conceptual
# Aspects of Experience</span></em>, edited by Hallvard J. <span class="smallcaps">Fossheim</span>, Tarjej <span class="smallcaps">Mandt
# Larsen</span>, and John Rickard <span class="smallcaps">Sageng</span>,
# pp. 193–211. Oslo: Unipub forlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2003c" role="listitem">
# —. 2003d. <span>“<span class="nocase">Dispositions, their Bases and
# Correlates – Meinong’s Analysis</span>.”</span> in <em><span class="nocase">Philosophy and Logic. In Search of the Polish
# Tradition. Essays in Honour of Jan Wole<span class="nocase">ń</span>ski
# on the Occasion of his 60th Birthday</span></em>, edited by Jaakko <span class="smallcaps">Hintikka</span>, Tadeusz <span class="smallcaps">Czarnecki</span>, Katarzyna <span class="smallcaps">Kijania-Placek</span>, Tomasz <span class="smallcaps">Placek</span>, and Artur <span class="smallcaps">Rojszczak</span>, pp. 193–212. <span>Synthese
# ...
# <em>Philosophiques</em> 42(2): 401–413.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2015e" role="listitem">
# —. 2015e. <span>“<span>Is Preference Primitive?</span>”</span> in
# <em><span class="nocase">Against Boredom. 17 Essays presented to
# Nils-Eric Sahlin</span></em>, edited by Ingmar <span class="smallcaps">Persson</span>, Göran <span class="smallcaps">Hermerén</span>, and E. <span class="smallcaps">Sjöstrand</span>, pp. 169–180. Lund: Fri tanke
# f<span>ö</span>rlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2015a" role="listitem">
# —. 2015b. <span>“<span>Secondary Meaning, Paraphraseability &amp;
# Pictures</span>.”</span> in <em><span>L’expression des
# <span>é</span>motions: m<span>é</span>langes
# d<span>é</span>di<span>é</span>s <span>à</span> Patrizia
# Lombardo</span></em>, edited by Martin <span class="smallcaps">Rueff</span> and Julien <span class="smallcaps">Zanetta</span>. Gen<span>è</span>ve:
# D<span>é</span>partement de Langue et de Litt<span>é</span>rature
# Fran<span>ç</span>aises Modernes.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2015c" role="listitem">
# —. 2015c. <span>“<span>Pr<span>é</span>cis de <span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span></span>.”</span>
# <em>Philosophiques</em> 42(2): 359–365.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2015d" role="listitem">
# —. 2015d. <span>“<span>R<span>é</span>ponse <span>à</span> mes critiques
# [<span class="citation" data-cites="plourde_j:2015">Plourde (<a href="#ref-c1-plourde_j:2015" role="doc-biblioref">2015</a>)</span>,
# <span class="citation" data-cites="frechette:2015a">Fréchette (<a href="#ref-c1-frechette:2015a" role="doc-biblioref">2015</a>)</span>,
# <span class="citation" data-cites="seron:2015a">Seron (<a href="#ref-c1-seron:2015a" role="doc-biblioref">2015</a>)</span> et
# <span class="citation" data-cites="philie:2015">Philie (<a href="#ref-c1-philie:2015" role="doc-biblioref">2015</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 401–413.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2015e" role="listitem">
# —. 2015e. <span>“<span>Is Preference Primitive?</span>”</span> in
# <em><span class="nocase">Against Boredom. 17 Essays presented to
# Nils-Eric Sahlin</span></em>, edited by Ingmar <span class="smallcaps">Persson</span>, Göran <span class="smallcaps">Hermerén</span>, and E. <span class="smallcaps">Sjöstrand</span>, pp. 169–180. Lund: Fri tanke
# f<span>ö</span>rlag.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016" role="listitem">
# —. 2016a. <span>“<span class="nocase">Happiness, Luck and
# Satisfaction</span>.”</span> <em>Argumenta</em> 2: 133–145.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016a" role="listitem">
# —. 2016b. <span>“<span class="nocase">How to Marry Phenomenology and
# Pragmatism. Scheler’s proposal</span>.”</span> in <em><span class="nocase">Papers dedicated to Anne Reboul</span></em>, edited by L.
# <span class="smallcaps">Dupuy</span>, A. <span class="smallcaps">Grabniza</span>, N. <span class="smallcaps">Foudon</span>, and Pierre <span class="smallcaps">Saint-Germier</span>. Lyon: D<span>é</span>partement
# de Philosophie.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016b" role="listitem">
# —. 2016c. <span>“<span class="nocase">Persons and Acts – Collective and
# Social. From Ontology to Politics</span>.”</span> in <em><span class="nocase">The Phenomenological Approach to Social
# Reality</span></em>, edited by Alessandro <span class="smallcaps">Salice</span> and Hans Bernhard <span class="smallcaps">Schmid</span>, pp. 17–45. <span class="nocase">Studies
# in the Philosophy of Sociality</span> n. 6. Dordrecht: Springer.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016c" role="listitem">
# —. 2016d. <span>“<span class="nocase">Foolishness and the Value of
# Knowledge</span>.”</span> in <em><span class="nocase">The Theory and
# Practice of Ontology</span></em>, edited by Leo <span class="smallcaps">Zaibert</span>, pp. 241–268. London: Palgrave
# Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016a" role="listitem">
# —. 2016b. <span>“<span class="nocase">How to Marry Phenomenology and
# Pragmatism. Scheler’s proposal</span>.”</span> in <em><span class="nocase">Papers dedicated to Anne Reboul</span></em>, edited by L.
# <span class="smallcaps">Dupuy</span>, A. <span class="smallcaps">Grabniza</span>, N. <span class="smallcaps">Foudon</span>, and Pierre <span class="smallcaps">Saint-Germier</span>. Lyon: D<span>é</span>partement
# de Philosophie.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016b" role="listitem">
# —. 2016c. <span>“<span class="nocase">Persons and Acts – Collective and
# Social. From Ontology to Politics</span>.”</span> in <em><span class="nocase">The Phenomenological Approach to Social
# Reality</span></em>, edited by Alessandro <span class="smallcaps">Salice</span> and Hans Bernhard <span class="smallcaps">Schmid</span>, pp. 17–45. <span class="nocase">Studies
# in the Philosophy of Sociality</span> n. 6. Dordrecht: Springer.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2016c" role="listitem">
# —. 2016d. <span>“<span class="nocase">Foolishness and the Value of
# Knowledge</span>.”</span> in <em><span class="nocase">The Theory and
# Practice of Ontology</span></em>, edited by Leo <span class="smallcaps">Zaibert</span>, pp. 241–268. London: Palgrave
# Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-cesalli-mulligan:2017" role="listitem">
# <span class="smallcaps">Cesalli</span>, Laurent and <span class="smallcaps">Mulligan</span>, Kevin. 2017. <span>“<span class="nocase">Marty and Brentano</span>.”</span> in <em><span class="nocase">The Routledge Handbook of Franz Brentano and the Brentano
# School</span></em>, edited by Uriah <span class="smallcaps">Kriegel</span>, pp. 251–263. <span class="nocase">Routledge Handbooks in Philosophy</span>. London:
# Routledge.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017" role="listitem">
# —. 2017a. <span>“<span class="nocase">Brentano’s Knowledge, Austrian
# Verificationisms, and Epistemic Accounts of Truth and
# Value</span>.”</span> <em>The Monist</em> 100(1): 88–105.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017a" role="listitem">
# —. 2017b. <span>“<span class="nocase">Thrills, Orgasms, Sadness, and
# Hysteria: Austro-German Criticisms of William James</span>.”</span> in
# <em><span class="nocase">Thinking about the Emotions: A Philosophical
# History</span></em>, edited by Alix A. <span class="smallcaps">Cohen</span> and Robert <span class="smallcaps">Stern</span>, pp. 223–252. <span>Mind Association
# Occasional Series</span>. Oxford: Oxford University Press, doi:<a href="https://doi.org/10.1093/oso/9780198766858.001.0001">10.1093/oso/9780198766858.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017b" role="listitem">
# —. 2017c. <span>“<span class="nocase">The Origins of Emotivism,
# Expressivism and the Error Theory: Marty, Scheler, Russell, Ogden &amp;
# Richards</span>.”</span> in <em><span class="nocase">Mind and Language –
# On the Philosophy of Anton Marty</span></em>, edited by Guillaume <span class="smallcaps">Fréchette</span> and Hamid <span class="smallcaps">Taieb</span>, pp. 149–168. <span>Phenomenology &amp;
# Mind</span> n. 19. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017c" role="listitem">
# —. 2017d. <span>“<span>Les relations – envers et contre
# tout</span>.”</span> in <em><span>Ontologie contemporaine:
# Identit<span>é</span>,structure et
# m<span>é</span>taontologie</span></em>, edited by Frédéric <span class="smallcaps">Nef</span>, Yann <span class="smallcaps">Schmitt</span>, and Luc <span class="smallcaps">Schneider</span>. <span>Textes
# cl<span>é</span>s</span>. Paris: Librairie philosophique Jean Vrin.
# <span>French translation of <span class="citation" data-cites="mulligan_k:1998">Mulligan, K. (<a href="#ref-c1-mulligan_k:1998" role="doc-biblioref">1998a</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017d" role="listitem">
# —. 2017e. <span>“<span class="nocase">Intentionality, Reasons and
# Motives</span>.”</span> in <em><span class="nocase">Intentionality and
# Action</span></em>, edited by Jesús <span class="smallcaps">Padilla
# Gálvez</span> and Margit <span class="smallcaps">Gaffal</span>, pp.
# 9–22. <span>Aporia</span> n. 10. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017e" role="listitem">
# —. 2017f. <span>“<span>Panentheistic Dualisms, Chaos and Values. The
# Metaphysics of Ehrenfels and Scheler</span>.”</span> in
# <em><span>Christian von Ehrenfels: Philosophie – Gestalttheorie –
# Kunst. <span>Ö</span>sterreichische Ideengeschichte im Fin de
# Si<span>è</span>cle</span></em>, edited by Ulf <span class="smallcaps">Hoefer</span> and Jutta <span class="smallcaps">Valent</span>, pp. 69–82. <span>Meinong Studies /
# Meinong Studien</span> n. 8. Berlin: de Gruyter, doi:<a href="https://doi.org/10.1515/9783110518306-005">10.1515/9783110518306-005</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017a" role="listitem">
# —. 2017b. <span>“<span class="nocase">Thrills, Orgasms, Sadness, and
# Hysteria: Austro-German Criticisms of William James</span>.”</span> in
# <em><span class="nocase">Thinking about the Emotions: A Philosophical
# History</span></em>, edited by Alix A. <span class="smallcaps">Cohen</span> and Robert <span class="smallcaps">Stern</span>, pp. 223–252. <span>Mind Association
# Occasional Series</span>. Oxford: Oxford University Press, doi:<a href="https://doi.org/10.1093/oso/9780198766858.001.0001">10.1093/oso/9780198766858.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017b" role="listitem">
# —. 2017c. <span>“<span class="nocase">The Origins of Emotivism,
# Expressivism and the Error Theory: Marty, Scheler, Russell, Ogden &amp;
# Richards</span>.”</span> in <em><span class="nocase">Mind and Language –
# On the Philosophy of Anton Marty</span></em>, edited by Guillaume <span class="smallcaps">Fréchette</span> and Hamid <span class="smallcaps">Taieb</span>, pp. 149–168. <span>Phenomenology &amp;
# Mind</span> n. 19. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017c" role="listitem">
# —. 2017d. <span>“<span>Les relations – envers et contre
# tout</span>.”</span> in <em><span>Ontologie contemporaine:
# Identit<span>é</span>,structure et
# m<span>é</span>taontologie</span></em>, edited by Frédéric <span class="smallcaps">Nef</span>, Yann <span class="smallcaps">Schmitt</span>, and Luc <span class="smallcaps">Schneider</span>. <span>Textes
# cl<span>é</span>s</span>. Paris: Librairie philosophique Jean Vrin.
# <span>French translation of <span class="citation" data-cites="mulligan_k:1998">Mulligan, K. (<a href="#ref-c1-mulligan_k:1998" role="doc-biblioref">1998a</a>)</span></span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017d" role="listitem">
# —. 2017e. <span>“<span class="nocase">Intentionality, Reasons and
# Motives</span>.”</span> in <em><span class="nocase">Intentionality and
# Action</span></em>, edited by Jesús <span class="smallcaps">Padilla
# Gálvez</span> and Margit <span class="smallcaps">Gaffal</span>, pp.
# 9–22. <span>Aporia</span> n. 10. Berlin: de Gruyter.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2017e" role="listitem">
# —. 2017f. <span>“<span>Panentheistic Dualisms, Chaos and Values. The
# Metaphysics of Ehrenfels and Scheler</span>.”</span> in
# <em><span>Christian von Ehrenfels: Philosophie – Gestalttheorie –
# Kunst. <span>Ö</span>sterreichische Ideengeschichte im Fin de
# Si<span>è</span>cle</span></em>, edited by Ulf <span class="smallcaps">Hoefer</span> and Jutta <span class="smallcaps">Valent</span>, pp. 69–82. <span>Meinong Studies /
# Meinong Studien</span> n. 8. Berlin: de Gruyter, doi:<a href="https://doi.org/10.1515/9783110518306-005">10.1515/9783110518306-005</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2018" role="listitem">
# —. 2018. <span>“<span class="nocase">Early Analytic Philosophy’s
# Austrian Dimensions</span>.”</span> in <em><span class="nocase">Eva
# Picardi on Language, Analysis and History</span></em>, edited by
# Annalisa <span class="smallcaps">Coliva</span>, Paolo <span class="smallcaps">Leonardi</span>, and Sebastiano <span class="smallcaps">Moruzzi</span>, pp. 7–30. London: Palgrave Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2019" role="listitem">
# —. 2019. <span>“<span class="nocase">Modes of Being and the
# Mind</span>.”</span> in <em><span class="nocase">Quo Vadis, Metaphysics?
# Essays in Honor of Peter van Inwagen</span></em>, edited by Mirosław
# <span class="smallcaps">Szatkowski</span>, pp. 183–202.
# <span>Philosophical Analysis</span> n. 81. Berlin: de Gruyter, doi:<a href="https://doi.org/10.1515/9783110664812">10.1515/9783110664812</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2020" role="listitem">
# —. 2020. <span>“<span>Austro-German Phenomenologists</span>.”</span> in
# <em><span class="nocase">The Routledge Handbook of Metaphysical
# Grounding</span></em>, edited by Michael J. <span class="smallcaps">Raven</span>, pp. 90–101. <span class="nocase">Routledge Handbooks in Philosophy</span>. London:
# Routledge, doi:<a href="https://doi.org/10.4324/9781351258845">10.4324/9781351258845</a>.
# </div>
# <div class="csl-entry" id="ref-c1-massin-mulligan:2021" role="listitem">
# <span class="smallcaps">Massin</span>, Olivier and <span class="smallcaps">Mulligan</span>, Kevin. 2021.
# <em><span>D<span>é</span>crire. La psychologie de Franz
# Brentano</span></em>. <span>Analyse et philosophie</span>. Paris:
# Librairie philosophique Jean Vrin.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2021" role="listitem">
# —. 2021. <span>“<span class="nocase">On Being Guided, Signals and Rules:
# From B<span class="nocase">ü</span>hler to Wittgenstein</span>.”</span>
# in <em><span class="nocase">Philosophy of Language in the Brentano
# School. Reassessing the Brentanian Legacy</span></em>, edited by Arnaud
# <span class="smallcaps">Dewalque</span>, Charlotte <span class="smallcaps">Gauvry</span>, and Sébastien <span class="smallcaps">Richard</span>, pp. 299–315. London: Palgrave
# Macmillan.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2022" role="listitem">
# —. 2022. <span>“<span class="nocase">Logic, Logical Norms, and
# (Normative) Grounding</span>.”</span> in <em><span class="nocase">Bolzano’s Philosophy of Grounding. Translations and
# Studies</span></em>, edited by Stefan <span class="smallcaps">Roski</span> and Benjamin Sebastian <span class="smallcaps">Schnieder</span>, pp. 244–275. Oxford: Oxford
# University Press, doi:<a href="https://doi.org/10.1093/oso/9780192847973.001.0001">10.1093/oso/9780192847973.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:2013d" role="listitem">
# —. 2013f. <span>“<span class="nocase">Novel Questions, Poetic Answers
# [Review of <span class="citation" data-cites="moore_aw:2012">Moore (<a href="#ref-c1-moore_aw:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span> <em>The Times
# Literary Supplement</em>, September, 22–23.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k-woodruff:unpub" role="listitem">
# <span class="smallcaps">Mulligan</span>, Kevin and <span class="smallcaps">Woodruff Smith</span>, David. n.d. <span>“<span class="nocase">Abstraction, Relations and Perception</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:unpub" role="listitem">
# —. n.d.a. <span>“<span class="nocase">The Roots of Reism</span>.”</span>
# <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:unpub-a" role="listitem">
# —. n.d.b. <span>“<span class="nocase">Austro-German Essence and
# Modality</span>.”</span> <span>Unpublished manuscript</span>.
# </div>
# <div class="csl-entry" id="ref-c1-mulligan_k:unpub-a" role="listitem">
# —. n.d.b. <span>“<span class="nocase">Austro-German Essence and
# Modality</span>.”</span> <span>Unpublished manuscript</span>.
# </div>

# %%
sub_further = [
    [
        div for div in divs if bib_dep in get_id(div)
    ]
        for bib_dep in bib_deps
]

# %%
sub_fur_flat = [item for sublist in sub_further for item in sublist]

# %%
print("\n".join([div.__str__() for div in sub_fur_flat]))
# Out:
# <div class="csl-entry" id="ref-c1-frechette:2015a" role="listitem">
# <span class="smallcaps">Fréchette</span>, Guillaume. 2015.
# <span>“<span>Le moment normatif dans la philosophie austro-allemande
# [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K.
# (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 375–384.
# </div>
# <div class="csl-entry" id="ref-c1-husserl_e:1984" role="listitem">
# <span class="smallcaps">Husserl</span>, Edmund. 1984. <em><span>Logische
# Untersuchungen. Zweiter Teil. Untersuchungen zur
# Ph<span>ä</span>nomenologie und Theorie der Erkenntnis</span></em>.
# <span>Husserliana</span> n. 19. Den Haag: Martinus Nijhoff Publishers.
# <span>Herausgegeben von Ursula Panzer</span>.
# </div>
# <div class="csl-entry" id="ref-c1-kuenne_w:2003" role="listitem">
# <span class="smallcaps">Künne</span>, Wolfgang. 2003. <em><span class="nocase">Conceptions of Truth</span></em>. Oxford: Oxford
# University Press, doi:<a href="https://doi.org/10.1093/0199241317.001.0001">10.1093/0199241317.001.0001</a>.
# </div>
# <div class="csl-entry" id="ref-c1-moore_aw:2012" role="listitem">
# <span class="smallcaps">Moore</span>, Adrian W. 2012. <em><span class="nocase">The Evolution of Modern Metaphysics: Making Sense of
# Things</span></em>. <span class="nocase">The Evolution of Modern
# Philosophy</span>. Cambridge: Cambridge University Press.
# </div>
# <div class="csl-entry" id="ref-c1-philie:2015" role="listitem">
# <span class="smallcaps">Philie</span>, Patrice. 2015.
# <span>“<span>Wittgenstein et Ortega sur les lois logiques de base [sur
# <span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 391–399.
# </div>
# <div class="csl-entry" id="ref-c1-plourde_j:2015" role="listitem">
# <span class="smallcaps">Plourde</span>, Jimmy. 2015.
# <span>“<span>Autonomie de la logique et fondements des
# modalit<span>é</span>s <em>de re</em> syntaxique et <em>de dicto</em>
# sur la modalit<span>é</span> <em>de re</em> ontique [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K. (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 367–373.
# </div>
# <div class="csl-entry" id="ref-c1-seron:2015a" role="listitem">
# <span class="smallcaps">Seron</span>, Denis. 2015. <span>“<span>Les
# couleurs, la ph<span>é</span>nom<span>é</span>nologie et la grammaire
# [sur <span class="citation" data-cites="mulligan_k:2012">Mulligan, K.
# (<a href="#ref-c1-mulligan_k:2012" role="doc-biblioref">2012</a>)</span>]</span>.”</span>
# <em>Philosophiques</em> 42(2): 385–389.
# </div>
