# %%
big_bib = "/home/alebg/philosophie-ch/Dropbox/philosophie-ch/dltc-biblio/biblio.bib"

# %%
def extract_bibkey(line: str) -> str:
    bracket_split = line.split("{")
    comma_split = bracket_split[1].split(",")
    bibkey = comma_split[0]
    return bibkey

# %%
from typing import Literal, NamedTuple


class Bibkey(NamedTuple):
    first_author: str
    other_authors: str | None
    year: int | Literal["unpub", "forthcoming"] | str
    year_suffix: str | None

class BibkeyError(NamedTuple):
    text: str
    position: int
    error: str

    def __str__(self) -> str:
        return f"'{self.text}' at line {self.position} --- '{self.error}'"


def parse_bibkey(text: str, text_position_d: dict[str, int]) -> Bibkey | BibkeyError:
    """
    Return either a Bibkey object, or a BibkeyError object to indicate a parsing error.
    """

    try:
        parts = text.split(":")
        if len(parts) != 2:
            raise ValueError(f"Unexpected number of bibkey parts for '{text}': '{parts}'")

        author_parts = parts[0].split("-")
        year_parts = parts[1]

        if len(author_parts) == 1:
            first_author = author_parts[0]
            other_authors = None
        elif len(author_parts) == 2:
            first_author = author_parts[0]
            other_authors = author_parts[1]
        else:
            raise ValueError(f"Unexpected bibkey author parts for '{text}': '{author_parts}'")

        char_index_type_d = {i: (char, char.isdigit()) for i, char in enumerate(year_parts)}

        year_l: list[str] = []
        int_breakpoint = None
        for value in char_index_type_d.items():
            i, (char, is_digit) = value
            if is_digit:
                year_l.append(char)
                int_breakpoint = i
            else:
                break

        if year_l != []:
            year_int = int(f"{''.join(year_l)}")
        else:
            year_int = None

        if int_breakpoint is not None:
            year_suffix = year_parts[int_breakpoint + 1 :]

        else:
            # all characters are non-digits
            year_suffix = "".join(year_parts)

        if year_suffix != "" and year_suffix not in ["unpub", "forthcoming"]:
            if len(year_suffix) > 1:
                if "unpub" not in year_suffix and "forthcoming" not in year_suffix:
                    print(f"WARNING: Unexpected year suffix for '{text}': '{year_suffix}'")
            elif len(year_suffix) == 1:
                if year_suffix.isdigit():
                    print(f"WARGNING: Unexpected year suffix for '{text}': '{year_suffix}'")

        if year_int is None and year_suffix is None:
            raise ValueError(f"Could not parse year for '{text}': '{year_parts}'")

        if year_int is None:
            return Bibkey(first_author=first_author, other_authors=other_authors, year=year_suffix, year_suffix="")

        else:
            return Bibkey(
                first_author=first_author, other_authors=other_authors, year=year_int, year_suffix=year_suffix
            )

    except ValueError as e:
        return BibkeyError(text, text_position_d[text] + 1, str(e))

# %%
with open(big_bib, "r") as f:
    bibkey_linenum_d = {
        extract_bibkey(line): i+1
        for i, line in enumerate(f.readlines())
    }


with open(big_bib, "r") as f:
    big_bib_len = len(f.readlines())

# %%
with open(big_bib, "r") as f:
    all_bibkeys = tuple(extract_bibkey(line) for line in f.readlines())

all_bibkeys_len = len(all_bibkeys)
assert all_bibkeys_len == big_bib_len, f"Expected {big_bib_len} bibkeys, found {all_bibkeys_len}"

all_bibkeys_uniq_len = len(frozenset(all_bibkeys))
assert all_bibkeys_len == all_bibkeys_uniq_len, f"Duplicate bibkeys found: {all_bibkeys_len} total, {all_bibkeys_uniq_len} unique"

parse_result = tuple(parse_bibkey(bk, bibkey_linenum_d) for bk in all_bibkeys)

error_results = tuple(result for result in parse_result if isinstance(result, BibkeyError))

if error_results:
    error_results_str = "\n".join(str(error_result) for error_result in error_results)
    error_results_len = len(error_results)
    raise ValueError(f"Found {error_results_len} errors while parsing bibkeys:\n{error_results_str}")
# Out:
# WARNING: Unexpected year suffix for 'burge_t:2003z2': 'z2'
# WARNING: Unexpected year suffix for 'burge_t:2003z3': 'z3'
# WARNING: Unexpected year suffix for 'burge_t:2003z4': 'z4'
# WARNING: Unexpected year suffix for 'danto:2013z1': 'z1'
# WARNING: Unexpected year suffix for 'davidson_d:1999z10': 'z10'
# WARNING: Unexpected year suffix for 'davidson_d:1999z11': 'z11'
# WARNING: Unexpected year suffix for 'davidson_d:1999z12': 'z12'
# WARNING: Unexpected year suffix for 'davidson_d:1999z13': 'z13'
# WARNING: Unexpected year suffix for 'davidson_d:1999z14': 'z14'
# WARNING: Unexpected year suffix for 'davidson_d:1999z15': 'z15'
# WARNING: Unexpected year suffix for 'davidson_d:1999z16': 'z16'
# WARNING: Unexpected year suffix for 'davidson_d:1999z17': 'z17'
# WARNING: Unexpected year suffix for 'davidson_d:1999z18': 'z18'
# WARNING: Unexpected year suffix for 'davidson_d:1999z19': 'z19'
# WARNING: Unexpected year suffix for 'davidson_d:1999z2': 'z2'
# WARNING: Unexpected year suffix for 'davidson_d:1999z3': 'z3'
# WARNING: Unexpected year suffix for 'davidson_d:1999z4': 'z4'
# WARNING: Unexpected year suffix for 'davidson_d:1999z5': 'z5'
# WARNING: Unexpected year suffix for 'davidson_d:1999z6': 'z6'
# WARNING: Unexpected year suffix for 'davidson_d:1999z7': 'z7'
# WARNING: Unexpected year suffix for 'davidson_d:1999z8': 'z8'
# WARNING: Unexpected year suffix for 'davidson_d:1999z9': 'z9'
# WARNING: Unexpected year suffix for 'dummett_mae:2007z2': 'z2'
# WARNING: Unexpected year suffix for 'hintikka_j:2006z2': 'z2'
# WARNING: Unexpected year suffix for 'hintikka_j:2006z3': 'z3'
# WARNING: Unexpected year suffix for 'hintikka_j:2006z4': 'z4'
# WARNING: Unexpected year suffix for 'hintikka_j:2006z5': 'z5'
# WARNING: Unexpected year suffix for 'hintikka_j:2006z6': 'z6'
# WARNING: Unexpected year suffix for 'ketland:undated-2': 'undated-2'
# WARNING: Unexpected year suffix for 'nasr_sh:2001z1': 'z1'
# WARNING: Unexpected year suffix for 'nasr_sh:2001z2': 'z2'
# WARNING: Unexpected year suffix for 'nasr_sh:2001z3': 'z3'
# WARNING: Unexpected year suffix for 'rorty_r:2010z2': 'z2'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z1': 'z1'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z10': 'z10'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z2': 'z2'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z3': 'z3'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z4': 'z4'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z5': 'z5'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z6': 'z6'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z7': 'z7'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z8': 'z8'
# WARNING: Unexpected year suffix for 'tymieniecka:1988z9': 'z9'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z1': 'z1'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z10': 'z10'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z11': 'z11'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z12': 'z12'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z13': 'z13'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z14': 'z14'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z15': 'z15'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z16': 'z16'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z17': 'z17'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z18': 'z18'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z19': 'z19'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z2': 'z2'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z20': 'z20'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z21': 'z21'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z3': 'z3'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z4': 'z4'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z5': 'z5'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z6': 'z6'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z7': 'z7'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z8': 'z8'
# WARNING: Unexpected year suffix for 'tymieniecka:2000z9': 'z9'
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 17
#      15 error_results_str = "\n".join(str(error_result) for error_result in error_results)
#      16 error_results_len = len(error_results)
# ---> 17 raise ValueError(f"Found {error_results_len} errors while parsing bibkeys:\n{error_results_str}")
#
# ValueError: Found 3 errors while parsing bibkeys:
# 'adorno_tw:kracauer:2020' at line 1156 --- 'Unexpected number of bibkey parts for 'adorno_tw:kracauer:2020': '['adorno_tw', 'kracauer', '2020']''
# 'lehrer_pm:etal:1986' at line 110197 --- 'Unexpected number of bibkey parts for 'lehrer_pm:etal:1986': '['lehrer_pm', 'etal', '1986']''
# 'open-science-collaboration:2015' at line 141090 --- 'Unexpected bibkey author parts for 'open-science-collaboration:2015': '['open', 'science', 'collaboration']''
