# %%
import polars as pl

# %%
ods_file = "/home/alebg/philosophie-ch/Dropbox/philosophie-ch/dltc-biblio/biblio-v7-table.ods"
df = pl.read_ods(ods_file, has_header=True, drop_empty_rows=True)

# %%
df["publisher"].drop_nulls().head(5)
# Out:
# shape: (0,)
# Series: 'publisher' [null]
# [
# ]

# %%
df["publisher"].shape
# Out:
# (209587,)

# %%
df.schema
# Out:
# Schema([('_to_do_general', Null),
#         ('_change_request', String),
#         ('entry_type', String),
#         ('bibkey', String),
#         ('author', String),
#         ('_author_ids', Null),
#         ('editor', Null),
#         ('_editor_ids', Null),
#         ('author_ids', Null),
#         ('options', Null),
#         ('shorthand', Null),
#         ('date', Int64),
#         ('pubstate', Null),
#         ('title', String),
#         ('_title_unicode', Null),
#         ('booktitle', Null),
#         ('crossref', String),
#         ('journal', String),
#         ('journal_id', Int64),
#         ('volume', Int64),
#         ('number', String),
#         ('pages', String),
#         ('eid', String),
#         ('series', Null),
#         ('address', String),
#         ('institution', Null),
#         ('school', String),
#         ('publisher', Null),
#         ('publisher_id', Null),
#         ('type', String),
#         ('edition', Null),
#         ('note', String),
# ...
