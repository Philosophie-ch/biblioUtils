# %%
import sys

sys.path.append('..')

# %%
from yaml import load, Loader
from dltc_backcatalog.logic_types import Author, Article, JournalIssue, author_full_name, journal_date, TMonth, TYear, MONTH_STR_INT, TGivenName, TFamilyName
from aletk.utils import remove_extra_whitespace
from typing import Dict, Tuple

from faker import Faker
fake = Faker()

# %%
dummy_authors = [
    Author(
        given_name=fake.name(),
        family_name=fake.name(),
        correspondence=fake.boolean(),
        email=fake.email(),
        institute=fake.company(),
        orcid=fake.uuid4()
    ) for _ in range(10)
]

# %%
dummy_articles = [
    Article(
        title=fake.sentence(),
        subtitle=fake.sentence(),
        abstract=remove_extra_whitespace(fake.text()),
        authors=[fake.random_element(dummy_authors) for _ in range(3)],
        first_page=fake.random_int(),
        last_page=fake.random_int(),
        doi=fake.uuid4(),
        galleys=fake.file_path(),
        keywords=[fake.word() for _ in range(5)],
    ) for _ in range(10)
]

# %%
dummy_journal_issue = JournalIssue(
    journal=fake.company(),
    volume=fake.random_int(),
    issue=fake.random_int(),
    month=fake.random_int(1, 12),
    year=fake.random_int(1947, 2020),
    first_page=fake.random_int(),
    doi=fake.uuid4(),
    issnprint=fake.uuid4(),
    title=fake.sentence(),
    editors=[fake.random_element(dummy_authors) for _ in range(2)],
    articles=dummy_articles
)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 dummy_journal_issue = JournalIssue(
#       2     journal=fake.company(),
#       3     volume=fake.random_int(),
#       4     issue=fake.random_int(),
#       5     month=fake.random_int(1, 12),
#       6     year=fake.random_int(1947, 2020),
#       7     first_page=fake.random_int(),
#       8     doi=fake.uuid4(),
#       9     issnprint=fake.uuid4(),
#      10     title=fake.sentence(),
#      11     editors=[fake.random_element(dummy_authors) for _ in range(2)],
#      12     articles=dummy_articles
#      13 )
#
# TypeError: JournalIssue.__init__() missing 1 required positional argument: 'issn'

# %%
dummy_journal_issue
# Out:
# JournalIssue(journal='Reese, Grimes and Pacheco', volume=235, issue=9920, month=9, year=1984, first_page=4470, doi='ba7d69e7-7eb1-407e-9027-2a130c24bee5', issnprint='2ba4a3ce-b4e8-4cff-a555-bc6eb0751765', title='Together plant difficult answer fill budget.', editors=[Author(given_name='Andrew Greene', family_name='Heather Martinez', correspondence=True, email='pperez@example.com', institute='Nichols Inc', orcid='1220106c-fc80-4804-be6f-0e7d8fc65f70'), Author(given_name='Tyler Vincent', family_name='Dean Tanner', correspondence=True, email='achen@example.com', institute='Schmidt Ltd', orcid='ce164e11-697f-44c3-a043-f1460957e2d8')], articles=[Article(title='Officer marriage bring throughout purpose.', subtitle='Her health certainly community field.', abstract='Drop focus natural record. Season service month until. Enjoy pick health.', authors=[Author(given_name='Ivan Rhodes', family_name='Richard Logan', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b'), Author(given_name='Tyler Vincent', family_name='Dean Tanner', correspondence=True, email='achen@example.com', institute='Schmidt Ltd', orcid='ce164e11-697f-44c3-a043-f1460957e2d8'), Author(given_name='Elizabeth Walker', family_name='Tamara Lee', correspondence=True, email='mariamiller@example.com', institute='Mcdaniel, Carson and Howell', orcid='73c8ee70-dc9a-46b2-ae3a-5b452fb038b7')], first_page=2071, last_page=9454, doi='80fb7ef2-1a36-454b-819f-00347b034a3e', galleys='/officer/morning.doc', keywords=['beat', 'difference', 'should', 'lead', 'gas']), Article(title='Hold magazine physical quickly bank provide still.', subtitle='Age activity number just since east.', abstract='Compare Mr evidence perhaps own. Throw loss almost dinner for gun. Increase carry describe stuff.', authors=[Author(given_name='Andrew Greene', family_name='Heather Martinez', correspondence=True, email='pperez@example.com', institute='Nichols Inc', orcid='1220106c-fc80-4804-be6f-0e7d8fc65f70'), Author(given_name='Ivan Rhodes', family_name='Richard Logan', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b'), Author(given_name='Ivan Rhodes', family_name='Richard Logan', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b')], first_page=7002, last_page=9237, doi='b8f6bd06-de8a-4fbf-ae69-0236d549dbd8', galleys='/lot/resource.js', keywords=['listen', 'source', 'instead', 'detail', 'ask']), Article(title='Art feel join trip crime.', subtitle='Attention increase such.', abstract='Statement wind than. Six majority material view someone Mr operation involve. Morning determine site large act candidate agency occur.', authors=[Author(given_name='Allison Beck', family_name='Christopher Moody', correspondence=True, email='michelenewman@example.com', institute='Bentley, Norris and Douglas', orcid='f2186d7b-e4f7-4ae4-9cfb-5bcec104f841'), Author(given_name='Briana Waters', family_name='Christopher Bryan', correspondence=True, email='martinezcynthia@example.net', institute='Huff Group', orcid='01384e6c-0b2f-4285-afea-18225a3d607b'), Author(given_name='Brianna Erickson', family_name='Linda Hanson', correspondence=True, email='denisehoward@example.org', institute='Taylor-Barber', orcid='e935a1ae-167b-45c3-8ab1-2094b4ef09b4')], first_page=6627, last_page=7204, doi='44283f49-656a-4ab2-aeaf-c332e62f038d', galleys='/sure/when.jpeg', keywords=['trade', 'rate', 'media', 'nation', 'PM']), Article(title='From run arm control adult.', subtitle='Anyone attention charge laugh stuff.', abstract='Small upon law everybody. Baby huge population crime sometimes involve. Over thus single once. Prove political society over owner never shake agree.', authors=[Author(given_name='Brianna Erickson', family_name='Linda Hanson', correspondence=True, email='denisehoward@example.org', institute='Taylor-Barber', orcid='e935a1ae-167b-45c3-8ab1-2094b4ef09b4'), ...

# %%
sorted_articles = sorted(dummy_articles, key=lambda x: x.first_page)

# %%
def safe_yaml_str(s: str) -> str:
    yaml_special_non_quote_chars = [':', '#', '|', '>', '&', '*', '{', '}', '[', ']', '%', '@', '`'] 
    if any(c in s for c in yaml_special_non_quote_chars):
        if '"' in s:
            return f"'{s}'"
        else:
            return f"\"{s}\""
    else:
        return s

def article_author_to_yaml_str(author: Author) -> str:
    name_s = f"  - name: {safe_yaml_str(author.given_name)} {author.family_name}"
    email_s = f"    email: {safe_yaml_str(author.email)}" if author.email else ""
    institute_s = f"    institute:\n    - {safe_yaml_str(author.institute)}" if author.institute else ""
    orcid_s = f"    ORCID: {safe_yaml_str(author.orcid)}" if author.orcid else ""
    correspondence_s = f"    correspondence: {str(author.correspondence).lower()}"

    l = (name_s, email_s, institute_s, orcid_s, correspondence_s)
    l_filtered = (x for x in l if x != "")
    s = "\n".join(l_filtered)

    return s

def keyword_to_yaml_str(keyword: str) -> str:
    s = f"- {safe_yaml_str(keyword)}"

    return s

def article_to_yaml_str(article: Article) -> str:
    title_s = f"- title: {safe_yaml_str(article.title)}"
    subtitle_s = f"  subtitle: {safe_yaml_str(article.subtitle)}" if article.subtitle else ""
    first_page_s = f"  first-page: {article.first_page}"
    last_page_s = f"  last-page: {article.last_page}"
    doi_s = f"  doi: {safe_yaml_str(article.doi)}"
    abstract_s = f"  abstract: |\n    {article.abstract}" if article.abstract else ""
    author_s = f"  author:\n{"\n".join((article_author_to_yaml_str(author)) for author in article.authors)}"
    galleys_s = f"  galleys:\n  - {safe_yaml_str(article.galleys)}" if article.galleys else ""
    keywords_s = f"  keywords:\n  {"\n  ".join((keyword_to_yaml_str(keyword)) for keyword in article.keywords)}" if article.keywords else ""

    l = (title_s, subtitle_s, first_page_s, last_page_s, doi_s, abstract_s, author_s, galleys_s, keywords_s)
    l_filtered = (x for x in l if x != "")
    s = "\n".join(l_filtered)

    return s


def journal_issue_editor_to_yaml_str(editor: Author) -> str:
    s = f"- {author_full_name(editor)}"

    return s

def journal_issue_to_yaml_str(journal_issue: JournalIssue) -> str:
    volume_s = f"volume: {journal_issue.volume}"
    issue_s = f"issue: {journal_issue.issue}"
    date_s = f"date: {journal_date(journal_issue)}"
    first_page_s = f"first-page: {journal_issue.first_page}"
    doi_s = f"doi: {safe_yaml_str(journal_issue.doi)}"
    issnprint_s = f"issnprint: {safe_yaml_str(journal_issue.issnprint)}"
    issuetitle_s = f"issuetitle: {safe_yaml_str(journal_issue.title)}"
    issueeditor_s = f"issueeditor:\n{"\n".join((journal_issue_editor_to_yaml_str(editor)) for editor in journal_issue.editors)}"
    articles_s = f"articles:\n{"\n".join((article_to_yaml_str(article)) for article in journal_issue.articles)}"

    l = (volume_s, issue_s, date_s, first_page_s, doi_s, issnprint_s, issuetitle_s, issueeditor_s, articles_s)
    l_filtered = (x for x in l if x != "")
    s = "\n".join(l_filtered)

    return s

# %%
print(journal_issue_to_yaml_str(dummy_journal_issue))
# Out:
# volume: 235
# issue: 9920
# date: September 1984
# first-page: 4470
# doi: ba7d69e7-7eb1-407e-9027-2a130c24bee5
# issnprint: 2ba4a3ce-b4e8-4cff-a555-bc6eb0751765
# issuetitle: Together plant difficult answer fill budget.
# issueeditor:
# - Heather Martinez, Andrew Greene
# - Dean Tanner, Tyler Vincent
# articles:
# - title: Officer marriage bring throughout purpose.
#   subtitle: Her health certainly community field.
#   first-page: 2071
#   last-page: 9454
#   doi: 80fb7ef2-1a36-454b-819f-00347b034a3e
#   abstract: |
#     Drop focus natural record. Season service month until. Enjoy pick health.
#   author:
#   - name: Ivan Rhodes Richard Logan
#     email: "kmeza@example.net"
#     institute:
#     - Baker-Ford
#     ORCID: 3ee7e250-afef-4abe-a5c7-1bb749145b7b
#     correspondence: true
#   - name: Tyler Vincent Dean Tanner
#     email: "achen@example.com"
#     institute:
#     - Schmidt Ltd
#     ORCID: ce164e11-697f-44c3-a043-f1460957e2d8
#     correspondence: true
#   - name: Elizabeth Walker Tamara Lee
#     email: "mariamiller@example.com"
#     institute:
#     - Mcdaniel, Carson and Howell
#     ORCID: 73c8ee70-dc9a-46b2-ae3a-5b452fb038b7
#     correspondence: true
#   galleys:
#   - /officer/morning.doc
#   keywords:
#   - beat
#   - difference
#   - should
#   - lead
#   - gas
# - title: Hold magazine physical quickly bank provide still.
#   subtitle: Age activity number just since east.
#   first-page: 7002
#   last-page: 9237
#   doi: b8f6bd06-de8a-4fbf-ae69-0236d549dbd8
#   abstract: |
#     Compare Mr evidence perhaps own. Throw loss almost dinner for gun. Increase carry describe stuff.
#   author:
#   - name: Andrew Greene Heather Martinez
#     email: "pperez@example.com"
#     institute:
#     - Nichols Inc
#     ORCID: 1220106c-fc80-4804-be6f-0e7d8fc65f70
#     correspondence: true
#   - name: Ivan Rhodes Richard Logan
#     email: "kmeza@example.net"
#     institute:
#     - Baker-Ford
#     ORCID: 3ee7e250-afef-4abe-a5c7-1bb749145b7b
#     correspondence: true
#   - name: Ivan Rhodes Richard Logan
#     email: "kmeza@example.net"
#     institute:
#     - Baker-Ford
#     ORCID: 3ee7e250-afef-4abe-a5c7-1bb749145b7b
#     correspondence: true
#   galleys:
#   - /lot/resource.js
#   keywords:
#   - listen
#   - source
#   - instead
#   - detail
#   - ask
# - title: Art feel join trip crime.
#   subtitle: Attention increase such.
#   first-page: 6627
#   last-page: 7204
#   doi: 44283f49-656a-4ab2-aeaf-c332e62f038d
#   abstract: |
#     Statement wind than. Six majority material view someone Mr operation involve. Morning determine site large act candidate agency occur.
#   author:
#   - name: Allison Beck Christopher Moody
#     email: "michelenewman@example.com"
#     institute:
#     - Bentley, Norris and Douglas
#     ORCID: f2186d7b-e4f7-4ae4-9cfb-5bcec104f841
#     correspondence: true
#   - name: Briana Waters Christopher Bryan
#     email: "martinezcynthia@example.net"
#     institute:
#     - Huff Group
#     ORCID: 01384e6c-0b2f-4285-afea-18225a3d607b
#     correspondence: true
#   - name: Brianna Erickson Linda Hanson
#     email: "denisehoward@example.org"
#     institute:
#     - Taylor-Barber
#     ORCID: e935a1ae-167b-45c3-8ab1-2094b4ef09b4
#     correspondence: true
#   galleys:
#   - /sure/when.jpeg
#   keywords:
#   - trade
#   - rate
#   - media
#   - nation
#   - PM
# - title: From run arm control adult.
#   subtitle: Anyone attention charge laugh stuff.
#   first-page: 3138
#   last-page: 2503
#   doi: 1bf63f0f-73dd-49a9-9d09-32a4f38451d5
#   abstract: |
#     Small upon law everybody. Baby huge population crime sometimes involve. Over thus single once. Prove political society over owner never shake agree.
#   author:
#   - name: Brianna Erickson Linda Hanson
#     email: "denisehoward@example.org"
#     institute:
#     - Taylor-Barber
#     ORCID: e935a1ae-167b-45c3-8ab1-2094b4ef09b4
#     correspondence: true
#   - name: Elizabeth Walker Tamara Lee
#     email: "mariamiller@example.com"
#     institute:
#     - Mcdaniel, Carson and Howell
#     ORCID: 73c8ee70-dc9a-46b2-ae3a-5b452fb038b7
#     correspondence: true
#   - name: Tyler Vincent Dean Tanner
#     email: "achen@example.com"
#     institute:
#     - Schmidt Ltd
#     ORCID: ce164e11-697f-44c3-a043-f1460957e2d8
#     correspondence: true
#   galleys:
#   - /step/enough.avi
#   keywords:
#   - likely
#   - road
#   - contain
#   - certain
#   - third
# - title: Improve we avoid live beat room.
#   subtitle: Article hit become president.
#   first-page: 4268
#   last-page: 2164
#   doi: b9813ea1-98e9-4793-acaa-aaa979927dfe
#   abstract: |
#     Decide child kid style on decide. Side action write. Use buy reflect expect should. Often opportunity your short small wish wide. Set baby final type design about finally.
#   author:
#   - name: Allison Beck Christopher Moody
#     email: "michelenewman@example.com"
#     institute:
#     - Bentley, Norris and Douglas
#     ORCID: f2186d7b-e4f7-4ae4-9cfb-5bcec104f841
#     correspondence: true
#   - name: Allison Beck Christopher Moody
#     email: "michelenewman@example.com"
#     institute:
#     - Bentley, Norris and Douglas
#     ORCID: f2186d7b-e4f7-4ae4-9cfb-5bcec104f841
#     correspondence: true
#   - name: Elizabeth Walker Tamara Lee
#     email: "mariamiller@example.com"
#     institute:
#     - Mcdaniel, Carson and Howell
#     ORCID: 73c8ee70-dc9a-46b2-ae3a-5b452fb038b7
#     correspondence: true
#   galleys:
#   - /whether/remember.numbers
#   keywords:
#   - owner
#   - professional
#   - hard
#   - space
#   - third
# - title: A party world range party throughout popular.
#   subtitle: Small piece data degree ready size.
#   first-page: 7570
#   last-page: 9909
#   doi: 4fbe0852-5434-4458-9772-1897ca3f9905
#   abstract: |
#     At hold something audience science study cold. Popular do or spend head also place center. Economic growth professor and significant building. Address past which whole record more far.
#   author:
#   - name: Erin Ross Matthew Adams
#     email: "richard92@example.net"
#     institute:
#     - Downs, Sanders and Lopez
#     ORCID: 10e8fb48-9cec-4c31-ac85-a7668dc0dfce
#     correspondence: true
#   - name: Briana Waters Christopher Bryan
#     email: "martinezcynthia@example.net"
#     institute:
#     - Huff Group
#     ORCID: 01384e6c-0b2f-4285-afea-18225a3d607b
#     correspondence: true
#   - name: Helen Andrews Tracy James
#     email: "williamsrebecca@example.com"
#     institute:
#     - Freeman LLC
#     ORCID: 98b9a92e-5a95-487b-a33b-6b973c052b01
#     correspondence: false
#   galleys:
#   - /executive/foreign.xlsx
#   keywords:
#   - simply
#   - camera
#   - woman
#   - wife
#   - actually
# - title: Heavy financial fight main.
#   subtitle: Point such shoulder reflect energy.
#   first-page: 8137
#   last-page: 3429
#   doi: c63d33b8-bd39-4620-9568-777ab429638f
#   abstract: |
#     Question fill six among sing beyond begin. Street better group threat focus certain. Standard per his guy.
#   author:
#   - name: Briana Waters Christopher Bryan
#     email: "martinezcynthia@example.net"
#     institute:
#     - Huff Group
#     ORCID: 01384e6c-0b2f-4285-afea-18225a3d607b
#     correspondence: true
#   - name: Erin Ross Matthew Adams
#     email: "richard92@example.net"
#     institute:
#     - Downs, Sanders and Lopez
#     ORCID: 10e8fb48-9cec-4c31-ac85-a7668dc0dfce
#     correspondence: true
#   - name: Elizabeth Walker Tamara Lee
#     email: "mariamiller@example.com"
#     institute:
#     - Mcdaniel, Carson and Howell
#     ORCID: 73c8ee70-dc9a-46b2-ae3a-5b452fb038b7
#     correspondence: true
#   galleys:
#   - /mind/matter.webm
#   keywords:
#   - police
#   - military
#   - when
#   - main
#   - though
# - title: Heart board hand receive.
#   subtitle: Who toward drop serve.
#   first-page: 1570
#   last-page: 6412
#   doi: b2f457b0-4dfd-42ed-9252-05d89e7eef6e
#   abstract: |
#     Before past over blue science plan. Past help inside deep business.
#   author:
#   - name: Ivan Rhodes Richard Logan
#     email: "kmeza@example.net"
#     institute:
#     - Baker-Ford
#     ORCID: 3ee7e250-afef-4abe-a5c7-1bb749145b7b
#     correspondence: true
#   - name: Ivan Rhodes Richard Logan
#     email: "kmeza@example.net"
#     institute:
#     - Baker-Ford
#     ORCID: 3ee7e250-afef-4abe-a5c7-1bb749145b7b
#     correspondence: true
#   - name: Brianna Erickson Linda Hanson
#     email: "denisehoward@example.org"
#     institute:
#     - Taylor-Barber
#     ORCID: e935a1ae-167b-45c3-8ab1-2094b4ef09b4
#     correspondence: true
#   galleys:
#   - /statement/collection.json
#   keywords:
#   - brother
#   - there
#   - not
#   - finally
#   - investment
# - title: Produce even responsibility computer exist.
#   subtitle: Perhaps tax dark major.
#   first-page: 8777
#   last-page: 4283
#   doi: d07a0f68-db92-4062-852e-919fdffced2b
#   abstract: |
#     Form trial happen bit toward Mrs. Mouth mean seek event recognize recent yourself. Kind traditional magazine. Six compare change. Day station receive so education money.
#   author:
#   - name: Briana Waters Christopher Bryan
#     email: "martinezcynthia@example.net"
#     institute:
#     - Huff Group
#     ORCID: 01384e6c-0b2f-4285-afea-18225a3d607b
#     correspondence: true
#   - name: James Lee Jody Wu
#     email: "baileycatherine@example.com"
#     institute:
#     - Jenkins, Sexton and Baker
#     ORCID: af150527-cb0b-4d37-a238-b19d5fb02161
#     correspondence: false
#   - name: Briana Waters Christopher Bryan
#     email: "martinezcynthia@example.net"
#     institute:
#     - Huff Group
#     ORCID: 01384e6c-0b2f-4285-afea-18225a3d607b
#     correspondence: true
#   galleys:
#   - /kitchen/late.html
#   keywords:
#   - learn
#   - experience
#   - network
#   - term
#   - officer
# - title: Minute central also civil threat range imagine sea.
#   subtitle: What here join describe.
#   first-page: 171
#   last-page: 1297
#   doi: 4a54681f-1f7f-4eeb-889e-cd7eda467f8d
#   abstract: |
#     Not wait other list energy example right. Heavy break PM message difficult style.
#   author:
#   - name: Brianna Erickson Linda Hanson
#     email: "denisehoward@example.org"
#     institute:
#     - Taylor-Barber
#     ORCID: e935a1ae-167b-45c3-8ab1-2094b4ef09b4
#     correspondence: true
#   - name: Elizabeth Walker Tamara Lee
#     email: "mariamiller@example.com"
#     institute:
#     - Mcdaniel, Carson and Howell
#     ORCID: 73c8ee70-dc9a-46b2-ae3a-5b452fb038b7
#     correspondence: true
#   - name: Helen Andrews Tracy James
#     email: "williamsrebecca@example.com"
#     institute:
#     - Freeman LLC
#     ORCID: 98b9a92e-5a95-487b-a33b-6b973c052b01
#     correspondence: false
#   galleys:
#   - /character/paper.avi
#   keywords:
#   - travel
#   - east
#   - anything
#   - list
#   - ok

# %%
with open('journal_issue.yaml', 'w') as f:
    f.write(journal_issue_to_yaml_str(dummy_journal_issue))

# %%
if []:
    print("empty list is true")
else:
    print("hey")
# Out:
# hey

# %%
def parse_month_year(month_year_raw: str) -> Tuple[TMonth, TYear]:
    if month_year_raw == "":
        raise ValueError(f"Could not parse '{month_year_raw}'. Please input a month-year date of the form 'January 2025'.")
    stripped = remove_extra_whitespace(month_year_raw)
    month_s, year_s = tuple(stripped.split(" "))
    month = MONTH_STR_INT[month_s]
    year = int(year_s)
    return month, year

def parse_editor_name(author_name_raw: str) -> Tuple[TGivenName, TFamilyName]:

    if author_name_raw == "":
        return "", ""

    split = author_name_raw.split(",")
    stripped = [remove_extra_whitespace(x) for x in split]

    if len(stripped) == 2:
        return stripped[1], stripped[0]
    if len(stripped) == 1:
        print(f"Warning: author name in YAML '{author_name_raw}' contains only one part")
        return stripped[0], ""
    else:
        print(f"Warning: could not parse author name '{author_name_raw}'. Skipping.")
        return "", ""

def read_journal_issue_from_yaml(filename: str, journal: str) -> JournalIssue:

    yaml: Dict[str, str | Dict[str, str | Dict[str, str]]] = load(open(filename, 'r'), Loader=Loader)

    month, year = parse_month_year(yaml.get('date', ""))

    journal_issue = JournalIssue(
        journal=journal,
        volume=yaml.get('volume', ""),
        issue=yaml.get('issue', ""),
        month=month,
        year=year,
        first_page=int(yaml.get('first-page', "")),
        doi=yaml.get('doi', ""),
        issn=yaml.get('issn', ""),
        issnprint=yaml.get('issnprint', ""),
        title=yaml.get('issuetitle', ""),

        editors=[Author(
            given_name=parse_editor_name(editor)[0],
            family_name=parse_editor_name(editor)[1],
            correspondence=False,
            email='',
            institute='',
            orcid=''
        ) for editor in yaml.get('issueeditor', "")],

        articles=[Article(
            title=article.get('title', ""),
            subtitle=article.get('subtitle', ""),
            abstract=remove_extra_whitespace(article.get('abstract', "")),
            authors=[Author(
                given_name=(author.get('name', "")),
                family_name="",
                correspondence=author.get('correspondence', ""),
                email=author.get('email', ""),
                institute=author.get('institute', [""])[0],
                orcid=author.get('ORCID', "")
            ) for author in article['author']],

            first_page=article.get('first-page', ""),
            last_page=article.get('last-page', ""),
            doi=article.get('doi', ""),
            galleys=article.get('galleys', [""])[0],
            keywords=[keyword for keyword in article.get('keywords', [])]

        ) for article in yaml['articles']]
    )

    return journal_issue

# %%
read_ji = read_journal_issue_from_yaml('journal_issue.yaml', "Test")

# %%
print(read_ji)
# Out:
# JournalIssue(journal='Test', volume=235, issue=9920, month=9, year=1984, first_page=4470, doi='ba7d69e7-7eb1-407e-9027-2a130c24bee5', issnprint='2ba4a3ce-b4e8-4cff-a555-bc6eb0751765', title='Together plant difficult answer fill budget.', editors=[Author(given_name='Andrew Greene', family_name='Heather Martinez', correspondence=False, email='', institute='', orcid=''), Author(given_name='Tyler Vincent', family_name='Dean Tanner', correspondence=False, email='', institute='', orcid='')], articles=[Article(title='Officer marriage bring throughout purpose.', subtitle='Her health certainly community field.', abstract='Drop focus natural record. Season service month until. Enjoy pick health.', authors=[Author(given_name='Ivan Rhodes Richard Logan', family_name='', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b'), Author(given_name='Tyler Vincent Dean Tanner', family_name='', correspondence=True, email='achen@example.com', institute='Schmidt Ltd', orcid='ce164e11-697f-44c3-a043-f1460957e2d8'), Author(given_name='Elizabeth Walker Tamara Lee', family_name='', correspondence=True, email='mariamiller@example.com', institute='Mcdaniel, Carson and Howell', orcid='73c8ee70-dc9a-46b2-ae3a-5b452fb038b7')], first_page=2071, last_page=9454, doi='80fb7ef2-1a36-454b-819f-00347b034a3e', galleys='/officer/morning.doc', keywords=['beat', 'difference', 'should', 'lead', 'gas']), Article(title='Hold magazine physical quickly bank provide still.', subtitle='Age activity number just since east.', abstract='Compare Mr evidence perhaps own. Throw loss almost dinner for gun. Increase carry describe stuff.', authors=[Author(given_name='Andrew Greene Heather Martinez', family_name='', correspondence=True, email='pperez@example.com', institute='Nichols Inc', orcid='1220106c-fc80-4804-be6f-0e7d8fc65f70'), Author(given_name='Ivan Rhodes Richard Logan', family_name='', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b'), Author(given_name='Ivan Rhodes Richard Logan', family_name='', correspondence=True, email='kmeza@example.net', institute='Baker-Ford', orcid='3ee7e250-afef-4abe-a5c7-1bb749145b7b')], first_page=7002, last_page=9237, doi='b8f6bd06-de8a-4fbf-ae69-0236d549dbd8', galleys='/lot/resource.js', keywords=['listen', 'source', 'instead', 'detail', 'ask']), Article(title='Art feel join trip crime.', subtitle='Attention increase such.', abstract='Statement wind than. Six majority material view someone Mr operation involve. Morning determine site large act candidate agency occur.', authors=[Author(given_name='Allison Beck Christopher Moody', family_name='', correspondence=True, email='michelenewman@example.com', institute='Bentley, Norris and Douglas', orcid='f2186d7b-e4f7-4ae4-9cfb-5bcec104f841'), Author(given_name='Briana Waters Christopher Bryan', family_name='', correspondence=True, email='martinezcynthia@example.net', institute='Huff Group', orcid='01384e6c-0b2f-4285-afea-18225a3d607b'), Author(given_name='Brianna Erickson Linda Hanson', family_name='', correspondence=True, email='denisehoward@example.org', institute='Taylor-Barber', orcid='e935a1ae-167b-45c3-8ab1-2094b4ef09b4')], first_page=6627, last_page=7204, doi='44283f49-656a-4ab2-aeaf-c332e62f038d', galleys='/sure/when.jpeg', keywords=['trade', 'rate', 'media', 'nation', 'PM']), Article(title='From run arm control adult.', subtitle='Anyone attention charge laugh stuff.', abstract='Small upon law everybody. Baby huge population crime sometimes involve. Over thus single once. Prove political society over owner never shake agree.', authors=[Author(given_name='Brianna Erickson Linda Hanson', family_name='', correspondence=True, email='denisehoward@example.org', institute='Taylor-Barber', orcid='e935a1ae-167b-45c3-8ab1-2094b4ef09b4'), Author(given_name='Elizabeth Walker Tamara Lee', family_name='', correspondence=True, email='mariamiller@example.com', institute='Mcdanie ...

# %%
dltc_read = read_journal_issue_from_yaml('dltc-backcatalog-model.yaml', "Dialectica")

# %%
with open('dltc-reconstructed.yaml', 'w') as file:
    file.write(journal_issue_to_yaml_str(dltc_read))
